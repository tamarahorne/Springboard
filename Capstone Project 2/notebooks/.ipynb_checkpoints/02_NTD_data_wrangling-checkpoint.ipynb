# %% [markdown]
# <a id='Capstone 2: National Transit Database'></a>

# %% [markdown]
# # Capstone 2: *National Transit Database*

# %% [markdown]
# ## 1.1 Table of Contents<a id='1.1_Contents'></a>
# * [1 Data wrangling](#1_Data_wrangling)
#   * [1.1 Table of Contents](#1.1_Contents)
#   * [1.2 Introduction](#1.2_Introduction)
#   * [1.3 Data Dictionary](#1.3_Data_Dictionary)
#   * [1.4 Importing the Dependencies](#1.4_Importing_the_Dependencies)
#   * [1.5 Importing the Data](#1.5_Importing_the_Data)
#   * [1.6 Exploring the Data](#1.6_Exploring_the_Data)
#       * [1.6.1 Missing Data](#1.6.1_Missing_Data)
#           * [1.6.1.1 The Three Unique Identifier Columns](#1.6.1.1_The_Three_Unique_Identifier_Columns)
#               * [1.6.1.1.1 Finding NaNs and Other Forms of Missing Data](#1.6.1.1.1_Finding_NaNs_and_Other_Forms_of_Missing_Data)
#               * [1.6.1.1.2 Removing the Rows of Data](#1.6.1.1.2_Removing_the_Rows_of_Data)
#           * [1.6.1.2 Primary UZA Name, Sq Miles, and Population](#1.6.1.2_Primary_UZA_Name_Sq_Miles_and_Population)
#               * [1.6.1.2.1 Finding a Data Source](#1.6.1.2.1_Finding_a_Data_Source)
#               * [1.6.1.2.2 Filling the NaNs](#1.6.1.2.2_Filling_the_NaNs)
#           * [1.6.1.3 Organization Type, Service Area Sq Miles, and Service Area Population](#1.6.1.3_Organization_Type_Service_Sq_Miles_and_Service_Area_Population)
#       * [1.6.2 Determining the Primary Identifier](#1.6.2_Determining_the_Primary_Identifier)
#           * [1.6.2.1 Comparing '5 DIgit NTD ID' and '4 Digit NTD ID'](#1.6.2.1_Comparing_5_DIgit_NTD_ID_and_4_Digit_NTD_ID)
#           * [1.6.2.2 Comparing '5 DIgit NTD ID' and 'Agency'](#1.6.2.2_Comparing_5_DIgit_NTD_ID_and_Agency)
#           * [1.6.2.3 The Winning Combination](#1.6.2.3_The_Winning_Combination)
#       * [1.6.3 Changing Data Type of 'Rail (Y/N)' Column](#1.6.3_Rail)
#   * [1.7 Save Data](#1.7_Save_Data)
#   * [1.8 Summary](#1.8_Summary)

# %% [markdown]
# ## 1.2 Introduction
# <a id='1.2_Introduction'></a>

# %% [markdown]
# When states find their metropolitan areas growing both in population and in spread, they often begin to consider additions to or expansions of their public transportation options.  The National Transit Database contains a wealth of information about accidents, injuries, and fatalities involving various forms of public transportation throughout the United States from 2014-present day.  The state departments of transportation would like to know which features have the greatest influence on safety for the various modes of transportation, so they can better understand which modes of public transportation would be good candidates for their growing metropolitan areas in the future.
#
# The National Transit Database (NTD) is a Monthly Modal Time Series database from the Federal Transit Administration (FTA) containing over 33,000 rows of data.  Each row of data contains the number accidents, injuries, or fatalities which occurred in each category during a given month for a particular agency.

# %% [markdown]
# ## 1.3 Data Dictionary
# <a id='1.3_Data_Dictionary'></a>

# %% [markdown]
# **Note:** *This table contains only the columns which benefitted from further explanation.  For a complete list of columns, please refer to section 1.5 of this notebook.*
#
#
#
# | Column Name | Definition      [NTD Glossary link](https://www.transit.dot.gov/ntd/national-transit-database-ntd-glossary)|
# |:---------|:-------------|
# |5 DIgit NTD ID|National Transit Database ID number currently in use|
# |4 Digit NTD ID|Legacy ID number|
# |Agency| Name of the Reporting Agency|
# |Organization Type|Distinguishes between government, private, and independent public agencies|
# |Mode|AR: Alaska Railroad|
# ||CB: Commuter Bus|
# ||CC: Cable Car|
# ||CR: Commuter Rail
# ||DR: Demand Response|
# ||FB: Ferryboat|
# ||HR: Heavy Rail|
# ||IP: Inclined Plane|
# ||LR: Light Rail|
# ||MB: Bus|
# ||MG: Monorail and Automated Guideway|
# ||PB: Publico|
# ||RB: Bus Rapid Transit|
# ||SR: Streetcar Rail|
# ||TB: Trolleybus|
# ||TR: Aerial Tramway|
# ||VP: Vanpool|
# ||YR: Hybrid Rail
# |Type of Service|DO: Directly Operated|
# ||PT: Purchased Transportation|
# ||TX: Taxi|
# ||TN: Transit Network Company (new TOS effective Sept 2019) [NTD Guidance](https://www.transit.dot.gov/sites/fta.dot.gov/files/docs/NTD%202108%20FRN%20Webinar%20Presentation.pdf)|
# |Primary UZA Code|*(see note below table)* Numerical ranking by urbanized area population size|
# |Primary UZA Name|*(see note below table)*|
# |Primary UZA Sq Miles|*(see note below table)*|
# |Primary UZA Population|*(see note below table)*|
#
#
# **Urbanized Area (UZA):** An urbanized area is an incorporated area with a population of 50,000 or more that is designated as such by the U.S. Department of Commerce, Bureau of the Census.
# The Census Bureau delineates urban areas after each decennial census by applying specified criteria to decennial census and other data.
#
# **Non-Rail Modes:**
# Transit modes whose vehicles typically operate on roadways - streets, highways or expressways, but may also operate on waterways (ferryboat (FB)) or via aerial cable (aerial tramways (TR)). Vehicles are typically powered by motors onboard the vehicle, with one exception, aerial tramway (TR) vehicles which are electrically powered by a motor not onboard the vehicle in order to pull the vehicle via an overhead cable. NTD recognizes eight non-rail modes:
# 1.   Aerial Tramway (TR)
# 2.   Bus (MB)
# 3.   Bus rapid transit (RB)
# 4.   Commuter bus (CB)
# 5.   Demand Response (DR)
# 6.   Demand taxi (DT)
# 7.   Ferryboat (FB)
# 8.   Jitney (JT)
# 9.   Publico (PB)
# 10.   Trolleybus (TB), and
# 11.   Vanpool (VP).

# %% [markdown]
# ## 1.4 Importing the Dependencies
# <a id='1.4_Importing_the_Dependencies'></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

pd.set_option('display.max_rows', 70)

# %% [markdown]
# ## 1.5 Importing the Data
# <a id='1.5_Importing_the_Data'></a>

# %% [markdown]
# [National Transit Database (NTD) Monthly Modal Time Series Information Page](https://datahub.transportation.gov/Public-Transit/Monthly-Modal-Time-Series/5ti2-5uiv)
#
# [National Transit Database (NTD) Monthly Modal Time Series Data](https://datahub.transportation.gov/Public-Transit/Monthly-Modal-Time-Series/5ti2-5uiv/data)
#
# <div class="alert alert-info">
#   <strong>Note:</strong> There are NANs in 'Rail (Y/N) so I cannot change the data type to bool right now.  This will be addressed later in the notebook.</a>
# </div>

# %%
file = 'Monthly_Modal_Time_Series.csv'
data = pd.read_csv(file, dtype={'5 DIgit NTD ID': str, '4 Digit NTD ID': str})
data.info()
# Out:
# /var/folders/b_/wjqzr1wd3b71cyr3q4f2zts40000gn/T/ipykernel_1932/2416012665.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file, dtype={'5 DIgit NTD ID': str, '4 Digit NTD ID': str})
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133196 entries, 0 to 133195
# Data columns (total 65 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   5 DIgit NTD ID                              133196 non-null  object
#  1   4 Digit NTD ID                              130151 non-null  object
#  2   Agency                                      133148 non-null  object
#  3   Organization Type                           128819 non-null  object
#  4   Mode                                        133148 non-null  object
#  5   Type of Service                             133148 non-null  object
#  6   Rail (Y/N)                                  133148 non-null  object
#  7   Primary UZA Code                            133196 non-null  int64
#  8   Primary UZA Name                            128807 non-null  object
#  9   Primary UZA Sq Miles                        128855 non-null  float64
#  10  Primary UZA Population                      128855 non-null  float64
#  11  Service Area Sq Miles                       128960 non-null  float64
#  12  Service Area Population                     128960 non-null  float64
#  13  Year                                        133196 non-null  int64
#  14  Month                                       133196 non-null  int64
#  15  Vehicles                                    133196 non-null  int64
#  16  Vehicle Revenue Miles                       133196 non-null  int64
#  17  Vehicle Revenue Hours                       133196 non-null  int64
#  18  Ridership                                   133196 non-null  int64
#  19  Collisions with Motor Vehicle               133196 non-null  int64
#  20  Collisions with Person                      133196 non-null  int64
#  21  Collisions with Fixed Object                133196 non-null  int64
#  22  Collisions with Rail Vehicle                133196 non-null  int64
#  23  Collisions with Bus Vehicle                 133196 non-null  int64
#  24  Collisions with Other                       133196 non-null  int64
#  25  Total Collisions                            133196 non-null  int64
#  26  Total Derailments                           133196 non-null  int64
#  27  Total Fires                                 133196 non-null  int64
#  28  Total Security Events                       133196 non-null  int64
#  29  Total Events Not Otherwise Classified       133196 non-null  int64
#  30  Total Events                                133196 non-null  int64
#  31  Passenger Fatalities                        133196 non-null  int64
#  32  People Waiting or Leaving Fatalities        133196 non-null  int64
#  33  Operator Fatalities                         133196 non-null  int64
#  34  Other Employee Fatalities                   133196 non-null  int64
#  35  Total Employee Fatalities                   133196 non-null  int64
#  36  Other Worker Fatalities                     133196 non-null  int64
#  37  Bicyclist Fatalities                        133196 non-null  int64
#  38  Pedestrian in Crosswalk Fatalities          133196 non-null  int64
#  39  Pedestrian Not in Crosswalk Fatalities      133196 non-null  int64
#  40  Pedestrian Crossing Tracks Fatalities       133196 non-null  int64
#  41  Pedestrian Walking Along Tracks Fatalities  133196 non-null  int64
#  42  Other Vehicle Occupant Fatalities           133196 non-null  int64
#  43  Other Fatalities                            133196 non-null  int64
#  44  Trespasser Fatalities                       133196 non-null  int64
#  45  Suicide Fatalities                          133196 non-null  int64
#  46  Total Other Fatalities                      133196 non-null  int64
#  47  Total Fatalities                            133196 non-null  int64
#  48  Passenger Injuries                          133196 non-null  int64
#  49  People Waiting or Leaving Injuries          133196 non-null  int64
#  50  Operator Injuries                           133196 non-null  int64
#  51  Other Employee Injuries                     133196 non-null  int64
#  52  Total Employee Injuries                     133196 non-null  int64
#  53  Other Worker Injuries                       133196 non-null  int64
#  54  Bicyclist Injuries                          133196 non-null  int64
#  55  Pedestrian in Corsswalk Injuries            133196 non-null  int64
#  56  Pedestrian Not in Crosswalk Injuries        133196 non-null  int64
#  57  Pedestrian Crossing Tracks Injuries         133196 non-null  int64
#  58  Pedestrian Walking Along Tracks Injuries    133196 non-null  int64
#  59  Other Vehicle Occupant Injuries             133196 non-null  int64
#  60  Other Injuries                              133196 non-null  int64
#  61  Trespasser Injuries                         133196 non-null  int64
#  62  Suicide Injuries                            133196 non-null  int64
#  63  Total Other Injuries                        133196 non-null  int64
#  64  Total Injuries                              133196 non-null  int64
# dtypes: float64(4), int64(53), object(8)
# memory usage: 66.1+ MB

# %%
data.shape
# Out:
# (133196, 65)

# %%
data.head()
# Out:
#   5 DIgit NTD ID 4 Digit NTD ID  \
# 0          00008           0008
# 1          00008           0008
# 2          20008           2008
# 3          20008           2008
# 4          20008           2008
#
#                                               Agency  \
# 0  Tri-County Metropolitan Transportation Distric...
# 1  Tri-County Metropolitan Transportation Distric...
# 2                          MTA New York City Transit
# 3                          MTA New York City Transit
# 4                          MTA New York City Transit
#
#                                    Organization Type Mode Type of Service  \
# 0  Independent Public Agency or Authority of Tran...   LR              DO
# 1  Independent Public Agency or Authority of Tran...   MB              DO
# 2  Subsidiary Unit of a Transit Agency, Reporting...   DR              PT
# 3  Subsidiary Unit of a Transit Agency, Reporting...   HR              DO
# 4  Subsidiary Unit of a Transit Agency, Reporting...   MB              DO
#
#   Rail (Y/N)  Primary UZA Code           Primary UZA Name  \
# 0       True                24            Portland, OR-WA
# 1      False                24            Portland, OR-WA
# 2      False                 1  New York-Newark, NY-NJ-CT
# 3       True                 1  New York-Newark, NY-NJ-CT
# 4      False                 1  New York-Newark, NY-NJ-CT
#
#    Primary UZA Sq Miles  ...  Pedestrian in Corsswalk Injuries  \
# 0                 524.0  ...                                 0
# 1                 524.0  ...                                 0
# 2                3450.0  ...                                 1
# 3                3450.0  ...                                 0
# 4                3450.0  ...                                 1
#
#    Pedestrian Not in Crosswalk Injuries  Pedestrian Crossing Tracks Injuries  \
# 0                                     0                                    0
# 1                                     1                                    0
# 2                                     2                                    0
# 3                                     0                                    0
# 4                                     2                                    0
#
#    Pedestrian Walking Along Tracks Injuries  Other Vehicle Occupant Injuries  \
# 0                                         0                                1
# 1                                         0                                3
# 2                                         0                                6
# 3                                         0                                0
# 4                                         2                               21
#
#    Other Injuries  Trespasser Injuries  Suicide Injuries  \
# 0               0                    0                 0
# 1               0                    0                 0
# 2               0                    0                 0
# 3               0                    0                 2
# 4               0                    0                 0
#
#    Total Other Injuries  Total Injuries
# 0                     1               1
# 1                     4              11
# 2                     9              17
# 3                     2               9
# 4                    27              42
#
# [5 rows x 65 columns]

# %% [markdown]
# **Visualizing a single entry**  This data was reported by Tri-County Metropolitan Transportation District for the month of January, 2014, and contains the number of accidents, injuries, or fatalities which occurred in their service area in each category during that month.

# %%
data[data.index==1].T
# Out:
#                                                                                             1
# 5 DIgit NTD ID                                                                          00008
# 4 Digit NTD ID                                                                           0008
# Agency                                      Tri-County Metropolitan Transportation Distric...
# Organization Type                           Independent Public Agency or Authority of Tran...
# Mode                                                                                       MB
# Type of Service                                                                            DO
# Rail (Y/N)                                                                              False
# Primary UZA Code                                                                           24
# Primary UZA Name                                                              Portland, OR-WA
# Primary UZA Sq Miles                                                                    524.0
# Primary UZA Population                                                              1849898.0
# Service Area Sq Miles                                                                   533.0
# Service Area Population                                                             1542044.0
# Year                                                                                     2014
# Month                                                                                       1
# Vehicles                                                                                  516
# Vehicle Revenue Miles                                                                 1605059
# Vehicle Revenue Hours                                                                  136485
# Ridership                                                                             5235300
# Collisions with Motor Vehicle                                                               3
# Collisions with Person                                                                      1
# Collisions with Fixed Object                                                                0
# Collisions with Rail Vehicle                                                                0
# Collisions with Bus Vehicle                                                                 0
# Collisions with Other                                                                       0
# Total Collisions                                                                            4
# Total Derailments                                                                           0
# Total Fires                                                                                 0
# Total Security Events                                                                       2
# Total Events Not Otherwise Classified                                                       0
# Total Events                                                                                6
# Passenger Fatalities                                                                        0
# People Waiting or Leaving Fatalities                                                        0
# Operator Fatalities                                                                         0
# Other Employee Fatalities                                                                   0
# Total Employee Fatalities                                                                   0
# Other Worker Fatalities                                                                     0
# Bicyclist Fatalities                                                                        0
# Pedestrian in Crosswalk Fatalities                                                          0
# Pedestrian Not in Crosswalk Fatalities                                                      0
# Pedestrian Crossing Tracks Fatalities                                                       0
# Pedestrian Walking Along Tracks Fatalities                                                  0
# Other Vehicle Occupant Fatalities                                                           0
# Other Fatalities                                                                            0
# Trespasser Fatalities                                                                       0
# Suicide Fatalities                                                                          0
# Total Other Fatalities                                                                      0
# Total Fatalities                                                                            0
# Passenger Injuries                                                                          5
# People Waiting or Leaving Injuries                                                          1
# Operator Injuries                                                                           0
# Other Employee Injuries                                                                     1
# Total Employee Injuries                                                                     1
# Other Worker Injuries                                                                       0
# Bicyclist Injuries                                                                          0
# Pedestrian in Corsswalk Injuries                                                            0
# Pedestrian Not in Crosswalk Injuries                                                        1
# Pedestrian Crossing Tracks Injuries                                                         0
# Pedestrian Walking Along Tracks Injuries                                                    0
# Other Vehicle Occupant Injuries                                                             3
# Other Injuries                                                                              0
# Trespasser Injuries                                                                         0
# Suicide Injuries                                                                            0
# Total Other Injuries                                                                        4
# Total Injuries                                                                             11

# %% [markdown]
# ## 1.6 Exploring the Data
# <a id='1.6_Exploring_the_Data'></a>

# %% [markdown]
# ### 1.6.1 Missing Data
# <a id='1.6.1_Missing_Data'></a>

# %% [markdown]
# Overview of missing data in the dataframe.

# %%
missing = pd.concat([data.isnull().sum(), 100 * data.isnull().mean()], axis=1)
missing.columns=['count', 'percent']
missing.sort_values(by='percent', ascending=False)
# Out:
#                                             count   percent
# Primary UZA Name                             4389  3.295144
# Organization Type                            4377  3.286135
# Primary UZA Sq Miles                         4341  3.259107
# Primary UZA Population                       4341  3.259107
# Service Area Sq Miles                        4236  3.180276
# Service Area Population                      4236  3.180276
# 4 Digit NTD ID                               3045  2.286105
# Rail (Y/N)                                     48  0.036037
# Type of Service                                48  0.036037
# Mode                                           48  0.036037
# Agency                                         48  0.036037
# People Waiting or Leaving Injuries              0  0.000000
# Trespasser Fatalities                           0  0.000000
# Passenger Injuries                              0  0.000000
# Total Fatalities                                0  0.000000
# Total Other Fatalities                          0  0.000000
# Suicide Fatalities                              0  0.000000
# 5 DIgit NTD ID                                  0  0.000000
# Other Fatalities                                0  0.000000
# Other Vehicle Occupant Fatalities               0  0.000000
# Pedestrian Walking Along Tracks Fatalities      0  0.000000
# Other Employee Injuries                         0  0.000000
# Pedestrian Crossing Tracks Fatalities           0  0.000000
# Operator Injuries                               0  0.000000
# Pedestrian Not in Crosswalk Injuries            0  0.000000
# Total Employee Injuries                         0  0.000000
# Other Worker Injuries                           0  0.000000
# Bicyclist Injuries                              0  0.000000
# Pedestrian in Corsswalk Injuries                0  0.000000
# Pedestrian in Crosswalk Fatalities              0  0.000000
# Pedestrian Crossing Tracks Injuries             0  0.000000
# Pedestrian Walking Along Tracks Injuries        0  0.000000
# Other Vehicle Occupant Injuries                 0  0.000000
# Other Injuries                                  0  0.000000
# Trespasser Injuries                             0  0.000000
# Suicide Injuries                                0  0.000000
# Total Other Injuries                            0  0.000000
# Pedestrian Not in Crosswalk Fatalities          0  0.000000
# People Waiting or Leaving Fatalities            0  0.000000
# Bicyclist Fatalities                            0  0.000000
# Other Worker Fatalities                         0  0.000000
# Primary UZA Code                                0  0.000000
# Year                                            0  0.000000
# Month                                           0  0.000000
# Vehicles                                        0  0.000000
# Vehicle Revenue Miles                           0  0.000000
# Vehicle Revenue Hours                           0  0.000000
# Ridership                                       0  0.000000
# Collisions with Motor Vehicle                   0  0.000000
# Collisions with Person                          0  0.000000
# Collisions with Fixed Object                    0  0.000000
# Collisions with Rail Vehicle                    0  0.000000
# Collisions with Bus Vehicle                     0  0.000000
# Collisions with Other                           0  0.000000
# Total Collisions                                0  0.000000
# Total Derailments                               0  0.000000
# Total Fires                                     0  0.000000
# Total Security Events                           0  0.000000
# Total Events Not Otherwise Classified           0  0.000000
# Total Events                                    0  0.000000
# Passenger Fatalities                            0  0.000000
# Operator Fatalities                             0  0.000000
# Other Employee Fatalities                       0  0.000000
# Total Employee Fatalities                       0  0.000000
# Total Injuries                                  0  0.000000

# %% [markdown]
# Visualizing the missing data.

# %%
missingpercent = (100 * data.isnull().mean())

plt.figure(figsize=(16,22))
ax = missingpercent.sort_values(ascending=True).plot(kind='barh', fontsize=14)
ax.set_title('Percentage of Data Missing from Columns in NTD', fontsize=30, pad=20)
ax.set_xlabel('Percentage', fontsize=20)
ax.set_ylabel('Column Name', fontsize=20)


# Function below adapted from (https://stackoverflow.com/questions/28931224/how-to-add-value-labels-on-a-bar-chart)

def add_value_labels(ax, spacing=5):
    """Add labels to the end of each bar in a bar chart."""

# For each bar: Place a label
for rect in ax.patches:
    # Get X and Y placement of label from rect
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2

    # Number of points between bar and label
    space = 5
    # Vertical alignment for positive values
    ha = 'left'

    # Use X value as label and format number with three decimal places
    label = "{:.3f}".format(x_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(space, 0),          # Horizontally shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        va='center',                # Vertically center label
        ha=ha)                      # Horizontally align label differently for
                                    # positive and negative values.

# Call the function
add_value_labels(ax)

# %% [markdown]
# #### 1.6.1.1 The Three Unique Identifier Columns
# <a id='1.6.1.1_The_Three_Unique_Identifier_Columns'></a>

# %% [markdown]
# The '5 DIgit NTD ID', '5 Digit NTD ID', and 'Agency' columns all have the possibility of being used as unique identifyers for this project.  In this section of the notebook, I'll explore these columns to make sure each row has data in at least one of those fields, I'll check for accuracy and oddities, and I'll see if any missing data in those fields can be discovered elsewhere and added in a responsible way.

# %% [markdown]
# ##### 1.6.1.1.1 Finding NaNs and Other Forms of Missing Data
# <a id='1.6.1.1.1_Finding_NaNs_and_Other_Forms_of_Missing_Data'></a>

# %% [markdown]
# As seen in the visualization above, there are no NaNs in the '5 DIgit NTD ID' field.

# %%
data[data['5 DIgit NTD ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [5 DIgit NTD ID, 4 Digit NTD ID, Agency, Organization Type, Mode, Type of Service, Rail (Y/N), Primary UZA Code, Primary UZA Name, Primary UZA Sq Miles, Primary UZA Population, Service Area Sq Miles, Service Area Population, Year, Month, Vehicles, Vehicle Revenue Miles, Vehicle Revenue Hours, Ridership, Collisions with Motor Vehicle, Collisions with Person, Collisions with Fixed Object, Collisions with Rail Vehicle, Collisions with Bus Vehicle, Collisions with Other, Total Collisions, Total Derailments, Total Fires, Total Security Events, Total Events Not Otherwise Classified, Total Events, Passenger Fatalities, People Waiting or Leaving Fatalities, Operator Fatalities, Other Employee Fatalities, Total Employee Fatalities, Other Worker Fatalities, Bicyclist Fatalities, Pedestrian in Crosswalk Fatalities, Pedestrian Not in Crosswalk Fatalities, Pedestrian Crossing Tracks Fatalities, Pedestrian Walking Along Tracks Fatalities, Other Vehicle Occupant Fatalities, Other Fatalities, Trespasser Fatalities, Suicide Fatalities, Total Other Fatalities, Total Fatalities, Passenger Injuries, People Waiting or Leaving Injuries, Operator Injuries, Other Employee Injuries, Total Employee Injuries, Other Worker Injuries, Bicyclist Injuries, Pedestrian in Corsswalk Injuries, Pedestrian Not in Crosswalk Injuries, Pedestrian Crossing Tracks Injuries, Pedestrian Walking Along Tracks Injuries, Other Vehicle Occupant Injuries, Other Injuries, Trespasser Injuries, Suicide Injuries, Total Other Injuries, Total Injuries]
# Index: []
#
# [0 rows x 65 columns]

# %% [markdown]
# When looking at the pairings of '5 DIgit NTD ID' and 'Agency', a quotation mark is found for "5 DIgit NTD ID" at index 246.

# %%
data[['5 DIgit NTD ID', 'Agency']].drop_duplicates().sort_values('5 DIgit NTD ID').head(50)
# Out:
#       5 DIgit NTD ID                                             Agency
# 246                "                                                NaN
# 9564           00001            King County Department of Metro Transit
# 3874           00002                          Spokane Transit Authority
# 4828           00003  Pierce County Transportation Benefit Area Auth...
# 6770           00005                                    City of Everett
# 7897           00006                                     City of Yakima
# 4855           00007                              Lane Transit District
# 0              00008  Tri-County Metropolitan Transportation Distric...
# 8599           00011                            Valley Regional Transit
# 6741           00012                          Municipality of Anchorage
# 10016          00016                                RiverCities Transit
# 7445           00018                               Ben Franklin Transit
# 3856           00019                                  Intercity Transit
# 6754           00020                                     Kitsap Transit
# 2963           00021                   Whatcom Transportation Authority
# 8499           00023                                    City of Seattle
# 7685           00024  Clark County Public Transportation Benefit Are...
# 4839           00025                   Salem Area Mass Transit District
# 9864           00028                                   County of Pierce
# 17             00029  Snohomish County Public Transportation Benefit...
# 8776           00034               Rogue Valley Transportation District
# 697            00035                           Washington State Ferries
# 150            00040     Central Puget Sound Regional Transit Authority
# 933            00041                        Alaska Railroad Corporation
# 1929           00043                                Chelan Douglas PTBA
# 3857           00044                                     Skagit Transit
# 50253          00046                                City of Wilsonville
# 6422           00047                                  City of Corvallis
# 2231           00049                            vRide, Inc. - Anchorage
# 1774           00054                         King County Ferry District
# 977            00057           Central Oregon Intergovernmental Council
# 5771           00058                                   City of Portland
# 57088          00376                              Ride Connection, Inc.
# 49378          00415                        Ada County Highway District
# 3840           10001              Rhode Island Public Transit Authority
# 7668           10003         Massachusetts Bay Transportation Authority
# 3841           10004                    Brockton Area Transit Authority
# 36             10005                  Lowell Regional Transit Authority
# 7169           10006            Southeastern Regional Transit Authority
# 6192           10007               Berkshire Regional Transit Authority
# 2895           10008                   Pioneer Valley Transit Authority
# 4789           10013        Merrimack Valley Regional Transit Authority
# 8662           10014               Worcester Regional Transit Authority
# 6156           10016                  Greater Portland Transit District
# 1941           10017                  Greater Hartford Transit District
# 6727           10040                    Southeast Area Transit District
# 945            10042                            Valley Transit District
# 556            10045  Connecticut Department of Transportation - CTT...
# 2881           10048  Connecticut Department of Transportation - CTT...
# 5992           10049                 Greater New Haven Transit District

# %% [markdown]
# A search for additional quotation marks in the '5 DIgit NTD ID' field reveals a total of 48 rows.

# %%
data[data['5 DIgit NTD ID']==r'"']
# Out:
#        5 DIgit NTD ID 4 Digit NTD ID Agency Organization Type Mode  \
# 246                 "            NaN    NaN               NaN  NaN
# 247                 "            NaN    NaN               NaN  NaN
# 248                 "            NaN    NaN               NaN  NaN
# 122815              "            NaN    NaN               NaN  NaN
# 122816              "            NaN    NaN               NaN  NaN
# 122817              "            NaN    NaN               NaN  NaN
# 122818              "            NaN    NaN               NaN  NaN
# 125320              "            NaN    NaN               NaN  NaN
# 125321              "            NaN    NaN               NaN  NaN
# 125322              "            NaN    NaN               NaN  NaN
# 125817              "            NaN    NaN               NaN  NaN
# 125818              "            NaN    NaN               NaN  NaN
# 125819              "            NaN    NaN               NaN  NaN
# 125820              "            NaN    NaN               NaN  NaN
# 125821              "            NaN    NaN               NaN  NaN
# 125822              "            NaN    NaN               NaN  NaN
# 127275              "            NaN    NaN               NaN  NaN
# 127276              "            NaN    NaN               NaN  NaN
# 127278              "            NaN    NaN               NaN  NaN
# 127492              "            NaN    NaN               NaN  NaN
# 127493              "            NaN    NaN               NaN  NaN
# 127494              "            NaN    NaN               NaN  NaN
# 127495              "            NaN    NaN               NaN  NaN
# 127496              "            NaN    NaN               NaN  NaN
# 127497              "            NaN    NaN               NaN  NaN
# 127974              "            NaN    NaN               NaN  NaN
# 127975              "            NaN    NaN               NaN  NaN
# 127976              "            NaN    NaN               NaN  NaN
# 127977              "            NaN    NaN               NaN  NaN
# 127978              "            NaN    NaN               NaN  NaN
# 127979              "            NaN    NaN               NaN  NaN
# 127980              "            NaN    NaN               NaN  NaN
# 127981              "            NaN    NaN               NaN  NaN
# 127982              "            NaN    NaN               NaN  NaN
# 127983              "            NaN    NaN               NaN  NaN
# 127984              "            NaN    NaN               NaN  NaN
# 127985              "            NaN    NaN               NaN  NaN
# 131473              "            NaN    NaN               NaN  NaN
# 131474              "            NaN    NaN               NaN  NaN
# 132865              "            NaN    NaN               NaN  NaN
# 132866              "            NaN    NaN               NaN  NaN
# 132867              "            NaN    NaN               NaN  NaN
# 132868              "            NaN    NaN               NaN  NaN
# 133191              "            NaN    NaN               NaN  NaN
# 133192              "            NaN    NaN               NaN  NaN
# 133193              "            NaN    NaN               NaN  NaN
# 133194              "            NaN    NaN               NaN  NaN
# 133195              "            NaN    NaN               NaN  NaN
#
#        Type of Service Rail (Y/N)  Primary UZA Code Primary UZA Name  \
# 246                NaN        NaN                 0              NaN
# 247                NaN        NaN                 0              NaN
# 248                NaN        NaN                 0              NaN
# 122815             NaN        NaN                 0              NaN
# 122816             NaN        NaN                 0              NaN
# 122817             NaN        NaN                 0              NaN
# 122818             NaN        NaN                 0              NaN
# 125320             NaN        NaN                 0              NaN
# 125321             NaN        NaN                 0              NaN
# 125322             NaN        NaN                 0              NaN
# 125817             NaN        NaN                 0              NaN
# 125818             NaN        NaN                 0              NaN
# 125819             NaN        NaN                 0              NaN
# 125820             NaN        NaN                 0              NaN
# 125821             NaN        NaN                 0              NaN
# 125822             NaN        NaN                 0              NaN
# 127275             NaN        NaN                 0              NaN
# 127276             NaN        NaN                 0              NaN
# 127278             NaN        NaN                 0              NaN
# 127492             NaN        NaN                 0              NaN
# 127493             NaN        NaN                 0              NaN
# 127494             NaN        NaN                 0              NaN
# 127495             NaN        NaN                 0              NaN
# 127496             NaN        NaN                 0              NaN
# 127497             NaN        NaN                 0              NaN
# 127974             NaN        NaN                 0              NaN
# 127975             NaN        NaN                 0              NaN
# 127976             NaN        NaN                 0              NaN
# 127977             NaN        NaN                 0              NaN
# 127978             NaN        NaN                 0              NaN
# 127979             NaN        NaN                 0              NaN
# 127980             NaN        NaN                 0              NaN
# 127981             NaN        NaN                 0              NaN
# 127982             NaN        NaN                 0              NaN
# 127983             NaN        NaN                 0              NaN
# 127984             NaN        NaN                 0              NaN
# 127985             NaN        NaN                 0              NaN
# 131473             NaN        NaN                 0              NaN
# 131474             NaN        NaN                 0              NaN
# 132865             NaN        NaN                 0              NaN
# 132866             NaN        NaN                 0              NaN
# 132867             NaN        NaN                 0              NaN
# 132868             NaN        NaN                 0              NaN
# 133191             NaN        NaN                 0              NaN
# 133192             NaN        NaN                 0              NaN
# 133193             NaN        NaN                 0              NaN
# 133194             NaN        NaN                 0              NaN
# 133195             NaN        NaN                 0              NaN
#
#         Primary UZA Sq Miles  ...  Pedestrian in Corsswalk Injuries  \
# 246                      0.0  ...                                 0
# 247                      0.0  ...                                 0
# 248                      0.0  ...                                 0
# 122815                   0.0  ...                                 0
# 122816                   0.0  ...                                 0
# 122817                   0.0  ...                                 0
# 122818                   0.0  ...                                 0
# 125320                   0.0  ...                                 0
# 125321                   0.0  ...                                 0
# 125322                   0.0  ...                                 0
# 125817                   0.0  ...                                 0
# 125818                   0.0  ...                                 0
# 125819                   0.0  ...                                 0
# 125820                   0.0  ...                                 0
# 125821                   0.0  ...                                 0
# 125822                   0.0  ...                                 0
# 127275                   0.0  ...                                 0
# 127276                   0.0  ...                                 0
# 127278                   0.0  ...                                 1
# 127492                   0.0  ...                                 0
# 127493                   0.0  ...                                 0
# 127494                   0.0  ...                                 0
# 127495                   0.0  ...                                 0
# 127496                   0.0  ...                                 0
# 127497                   0.0  ...                                 0
# 127974                   0.0  ...                                 0
# 127975                   0.0  ...                                 0
# 127976                   0.0  ...                                 0
# 127977                   0.0  ...                                 0
# 127978                   0.0  ...                                 0
# 127979                   0.0  ...                                 0
# 127980                   0.0  ...                                 0
# 127981                   0.0  ...                                 0
# 127982                   0.0  ...                                 0
# 127983                   0.0  ...                                 0
# 127984                   0.0  ...                                 0
# 127985                   0.0  ...                                 0
# 131473                   0.0  ...                                 0
# 131474                   0.0  ...                                 0
# 132865                   0.0  ...                                 0
# 132866                   0.0  ...                                 0
# 132867                   0.0  ...                                 1
# 132868                   0.0  ...                                 0
# 133191                   0.0  ...                                 0
# 133192                   0.0  ...                                 0
# 133193                   0.0  ...                                 0
# 133194                   0.0  ...                                 0
# 133195                   0.0  ...                                 0
#
#         Pedestrian Not in Crosswalk Injuries  \
# 246                                        0
# 247                                        0
# 248                                        0
# 122815                                     0
# 122816                                     0
# 122817                                     0
# 122818                                     0
# 125320                                     0
# 125321                                     0
# 125322                                     0
# 125817                                     0
# 125818                                     0
# 125819                                     0
# 125820                                     0
# 125821                                     0
# 125822                                     0
# 127275                                     0
# 127276                                     0
# 127278                                     1
# 127492                                     0
# 127493                                     0
# 127494                                     0
# 127495                                     0
# 127496                                     0
# 127497                                     0
# 127974                                     0
# 127975                                     0
# 127976                                     0
# 127977                                     0
# 127978                                     0
# 127979                                     0
# 127980                                     0
# 127981                                     0
# 127982                                     0
# 127983                                     0
# 127984                                     0
# 127985                                     0
# 131473                                     0
# 131474                                     0
# 132865                                     0
# 132866                                     0
# 132867                                     0
# 132868                                     0
# 133191                                     0
# 133192                                     0
# 133193                                     0
# 133194                                     0
# 133195                                     0
#
#         Pedestrian Crossing Tracks Injuries  \
# 246                                       0
# 247                                       0
# 248                                       0
# 122815                                    0
# 122816                                    0
# 122817                                    0
# 122818                                    0
# 125320                                    0
# 125321                                    0
# 125322                                    0
# 125817                                    0
# 125818                                    0
# 125819                                    0
# 125820                                    0
# 125821                                    0
# 125822                                    0
# 127275                                    0
# 127276                                    0
# 127278                                    0
# 127492                                    0
# 127493                                    0
# 127494                                    0
# 127495                                    0
# 127496                                    0
# 127497                                    0
# 127974                                    0
# 127975                                    0
# 127976                                    0
# 127977                                    0
# 127978                                    0
# 127979                                    0
# 127980                                    0
# 127981                                    0
# 127982                                    0
# 127983                                    0
# 127984                                    0
# 127985                                    0
# 131473                                    0
# 131474                                    0
# 132865                                    0
# 132866                                    0
# 132867                                    0
# 132868                                    0
# 133191                                    0
# 133192                                    0
# 133193                                    0
# 133194                                    0
# 133195                                    0
#
#         Pedestrian Walking Along Tracks Injuries  \
# 246                                            0
# 247                                            0
# 248                                            0
# 122815                                         0
# 122816                                         0
# 122817                                         0
# 122818                                         0
# 125320                                         0
# 125321                                         0
# 125322                                         0
# 125817                                         0
# 125818                                         0
# 125819                                         0
# 125820                                         0
# 125821                                         0
# 125822                                         0
# 127275                                         0
# 127276                                         0
# 127278                                         0
# 127492                                         0
# 127493                                         0
# 127494                                         0
# 127495                                         0
# 127496                                         0
# 127497                                         0
# 127974                                         0
# 127975                                         0
# 127976                                         0
# 127977                                         0
# 127978                                         0
# 127979                                         0
# 127980                                         0
# 127981                                         0
# 127982                                         0
# 127983                                         0
# 127984                                         0
# 127985                                         0
# 131473                                         0
# 131474                                         0
# 132865                                         0
# 132866                                         0
# 132867                                         0
# 132868                                         0
# 133191                                         0
# 133192                                         0
# 133193                                         0
# 133194                                         0
# 133195                                         0
#
#         Other Vehicle Occupant Injuries  Other Injuries  Trespasser Injuries  \
# 246                                   0               0                    0
# 247                                   0               0                    0
# 248                                   0               0                    0
# 122815                                0               0                    0
# 122816                                0               0                    0
# 122817                                0               0                    0
# 122818                                0               0                    0
# 125320                                1               0                    0
# 125321                                0               0                    0
# 125322                                0               0                    0
# 125817                                0               0                    0
# 125818                                0               0                    0
# 125819                                0               0                    0
# 125820                                0               0                    0
# 125821                                0               0                    0
# 125822                                0               0                    0
# 127275                                0               0                    0
# 127276                                1               0                    0
# 127278                                1               0                    0
# 127492                                0               0                    0
# 127493                                0               0                    0
# 127494                                0               0                    0
# 127495                                0               0                    0
# 127496                                0               0                    0
# 127497                                0               0                    0
# 127974                                0               0                    0
# 127975                                0               0                    0
# 127976                                0               0                    0
# 127977                                0               0                    0
# 127978                                0               0                    0
# 127979                                0               0                    0
# 127980                                0               0                    0
# 127981                                0               0                    0
# 127982                                0               0                    0
# 127983                                0               0                    0
# 127984                                0               0                    0
# 127985                                0               0                    0
# 131473                                0               0                    0
# 131474                                0               0                    0
# 132865                                2               0                    0
# 132866                                0               0                    0
# 132867                                0               0                    0
# 132868                                0               0                    0
# 133191                                0               0                    0
# 133192                                0               0                    0
# 133193                                0               0                    0
# 133194                                0               0                    0
# 133195                                0               0                    0
#
#         Suicide Injuries  Total Other Injuries  Total Injuries
# 246                    0                     0               0
# 247                    0                     0               0
# 248                    0                     0               0
# 122815                 0                     0               0
# 122816                 0                     0               0
# 122817                 0                     0               0
# 122818                 0                     0               0
# 125320                 0                     1               1
# 125321                 0                     0               0
# 125322                 0                     1               1
# 125817                 0                     0               0
# 125818                 0                     0               0
# 125819                 0                     0               0
# 125820                 0                     0               0
# 125821                 0                     0               0
# 125822                 0                     0               0
# 127275                 0                     0               0
# 127276                 0                     1               1
# 127278                 0                     3               3
# 127492                 0                     0               0
# 127493                 0                     0               0
# 127494                 0                     0               0
# 127495                 0                     0               0
# 127496                 0                     0               0
# 127497                 0                     0               0
# 127974                 0                     0               0
# 127975                 0                     0               0
# 127976                 0                     0               0
# 127977                 0                     0               0
# 127978                 0                     0               0
# 127979                 0                     0               0
# 127980                 0                     0               0
# 127981                 0                     0               0
# 127982                 0                     0               0
# 127983                 0                     0               0
# 127984                 0                     0               0
# 127985                 0                     0               0
# 131473                 0                     0               0
# 131474                 0                     0               0
# 132865                 0                     2               2
# 132866                 0                     0               7
# 132867                 0                     1               2
# 132868                 0                     0               0
# 133191                 0                     0               0
# 133192                 0                     0               0
# 133193                 0                     0               0
# 133194                 0                     0               0
# 133195                 0                     0               0
#
# [48 rows x 65 columns]

# %% [markdown]
# Searching for NaNs in 'Agency' reveals the same 48 rows.  Since these rows contain no useful way to identify where the data is coming from (ie. no agency name, id number, or even organization or service type or mode) these rows are not useful for this project and can be removed.

# %%
data[data['Agency'].isna()]
# Out:
#        5 DIgit NTD ID 4 Digit NTD ID Agency Organization Type Mode  \
# 246                 "            NaN    NaN               NaN  NaN
# 247                 "            NaN    NaN               NaN  NaN
# 248                 "            NaN    NaN               NaN  NaN
# 122815              "            NaN    NaN               NaN  NaN
# 122816              "            NaN    NaN               NaN  NaN
# 122817              "            NaN    NaN               NaN  NaN
# 122818              "            NaN    NaN               NaN  NaN
# 125320              "            NaN    NaN               NaN  NaN
# 125321              "            NaN    NaN               NaN  NaN
# 125322              "            NaN    NaN               NaN  NaN
# 125817              "            NaN    NaN               NaN  NaN
# 125818              "            NaN    NaN               NaN  NaN
# 125819              "            NaN    NaN               NaN  NaN
# 125820              "            NaN    NaN               NaN  NaN
# 125821              "            NaN    NaN               NaN  NaN
# 125822              "            NaN    NaN               NaN  NaN
# 127275              "            NaN    NaN               NaN  NaN
# 127276              "            NaN    NaN               NaN  NaN
# 127278              "            NaN    NaN               NaN  NaN
# 127492              "            NaN    NaN               NaN  NaN
# 127493              "            NaN    NaN               NaN  NaN
# 127494              "            NaN    NaN               NaN  NaN
# 127495              "            NaN    NaN               NaN  NaN
# 127496              "            NaN    NaN               NaN  NaN
# 127497              "            NaN    NaN               NaN  NaN
# 127974              "            NaN    NaN               NaN  NaN
# 127975              "            NaN    NaN               NaN  NaN
# 127976              "            NaN    NaN               NaN  NaN
# 127977              "            NaN    NaN               NaN  NaN
# 127978              "            NaN    NaN               NaN  NaN
# 127979              "            NaN    NaN               NaN  NaN
# 127980              "            NaN    NaN               NaN  NaN
# 127981              "            NaN    NaN               NaN  NaN
# 127982              "            NaN    NaN               NaN  NaN
# 127983              "            NaN    NaN               NaN  NaN
# 127984              "            NaN    NaN               NaN  NaN
# 127985              "            NaN    NaN               NaN  NaN
# 131473              "            NaN    NaN               NaN  NaN
# 131474              "            NaN    NaN               NaN  NaN
# 132865              "            NaN    NaN               NaN  NaN
# 132866              "            NaN    NaN               NaN  NaN
# 132867              "            NaN    NaN               NaN  NaN
# 132868              "            NaN    NaN               NaN  NaN
# 133191              "            NaN    NaN               NaN  NaN
# 133192              "            NaN    NaN               NaN  NaN
# 133193              "            NaN    NaN               NaN  NaN
# 133194              "            NaN    NaN               NaN  NaN
# 133195              "            NaN    NaN               NaN  NaN
#
#        Type of Service Rail (Y/N)  Primary UZA Code Primary UZA Name  \
# 246                NaN        NaN                 0              NaN
# 247                NaN        NaN                 0              NaN
# 248                NaN        NaN                 0              NaN
# 122815             NaN        NaN                 0              NaN
# 122816             NaN        NaN                 0              NaN
# 122817             NaN        NaN                 0              NaN
# 122818             NaN        NaN                 0              NaN
# 125320             NaN        NaN                 0              NaN
# 125321             NaN        NaN                 0              NaN
# 125322             NaN        NaN                 0              NaN
# 125817             NaN        NaN                 0              NaN
# 125818             NaN        NaN                 0              NaN
# 125819             NaN        NaN                 0              NaN
# 125820             NaN        NaN                 0              NaN
# 125821             NaN        NaN                 0              NaN
# 125822             NaN        NaN                 0              NaN
# 127275             NaN        NaN                 0              NaN
# 127276             NaN        NaN                 0              NaN
# 127278             NaN        NaN                 0              NaN
# 127492             NaN        NaN                 0              NaN
# 127493             NaN        NaN                 0              NaN
# 127494             NaN        NaN                 0              NaN
# 127495             NaN        NaN                 0              NaN
# 127496             NaN        NaN                 0              NaN
# 127497             NaN        NaN                 0              NaN
# 127974             NaN        NaN                 0              NaN
# 127975             NaN        NaN                 0              NaN
# 127976             NaN        NaN                 0              NaN
# 127977             NaN        NaN                 0              NaN
# 127978             NaN        NaN                 0              NaN
# 127979             NaN        NaN                 0              NaN
# 127980             NaN        NaN                 0              NaN
# 127981             NaN        NaN                 0              NaN
# 127982             NaN        NaN                 0              NaN
# 127983             NaN        NaN                 0              NaN
# 127984             NaN        NaN                 0              NaN
# 127985             NaN        NaN                 0              NaN
# 131473             NaN        NaN                 0              NaN
# 131474             NaN        NaN                 0              NaN
# 132865             NaN        NaN                 0              NaN
# 132866             NaN        NaN                 0              NaN
# 132867             NaN        NaN                 0              NaN
# 132868             NaN        NaN                 0              NaN
# 133191             NaN        NaN                 0              NaN
# 133192             NaN        NaN                 0              NaN
# 133193             NaN        NaN                 0              NaN
# 133194             NaN        NaN                 0              NaN
# 133195             NaN        NaN                 0              NaN
#
#         Primary UZA Sq Miles  ...  Pedestrian in Corsswalk Injuries  \
# 246                      0.0  ...                                 0
# 247                      0.0  ...                                 0
# 248                      0.0  ...                                 0
# 122815                   0.0  ...                                 0
# 122816                   0.0  ...                                 0
# 122817                   0.0  ...                                 0
# 122818                   0.0  ...                                 0
# 125320                   0.0  ...                                 0
# 125321                   0.0  ...                                 0
# 125322                   0.0  ...                                 0
# 125817                   0.0  ...                                 0
# 125818                   0.0  ...                                 0
# 125819                   0.0  ...                                 0
# 125820                   0.0  ...                                 0
# 125821                   0.0  ...                                 0
# 125822                   0.0  ...                                 0
# 127275                   0.0  ...                                 0
# 127276                   0.0  ...                                 0
# 127278                   0.0  ...                                 1
# 127492                   0.0  ...                                 0
# 127493                   0.0  ...                                 0
# 127494                   0.0  ...                                 0
# 127495                   0.0  ...                                 0
# 127496                   0.0  ...                                 0
# 127497                   0.0  ...                                 0
# 127974                   0.0  ...                                 0
# 127975                   0.0  ...                                 0
# 127976                   0.0  ...                                 0
# 127977                   0.0  ...                                 0
# 127978                   0.0  ...                                 0
# 127979                   0.0  ...                                 0
# 127980                   0.0  ...                                 0
# 127981                   0.0  ...                                 0
# 127982                   0.0  ...                                 0
# 127983                   0.0  ...                                 0
# 127984                   0.0  ...                                 0
# 127985                   0.0  ...                                 0
# 131473                   0.0  ...                                 0
# 131474                   0.0  ...                                 0
# 132865                   0.0  ...                                 0
# 132866                   0.0  ...                                 0
# 132867                   0.0  ...                                 1
# 132868                   0.0  ...                                 0
# 133191                   0.0  ...                                 0
# 133192                   0.0  ...                                 0
# 133193                   0.0  ...                                 0
# 133194                   0.0  ...                                 0
# 133195                   0.0  ...                                 0
#
#         Pedestrian Not in Crosswalk Injuries  \
# 246                                        0
# 247                                        0
# 248                                        0
# 122815                                     0
# 122816                                     0
# 122817                                     0
# 122818                                     0
# 125320                                     0
# 125321                                     0
# 125322                                     0
# 125817                                     0
# 125818                                     0
# 125819                                     0
# 125820                                     0
# 125821                                     0
# 125822                                     0
# 127275                                     0
# 127276                                     0
# 127278                                     1
# 127492                                     0
# 127493                                     0
# 127494                                     0
# 127495                                     0
# 127496                                     0
# 127497                                     0
# 127974                                     0
# 127975                                     0
# 127976                                     0
# 127977                                     0
# 127978                                     0
# 127979                                     0
# 127980                                     0
# 127981                                     0
# 127982                                     0
# 127983                                     0
# 127984                                     0
# 127985                                     0
# 131473                                     0
# 131474                                     0
# 132865                                     0
# 132866                                     0
# 132867                                     0
# 132868                                     0
# 133191                                     0
# 133192                                     0
# 133193                                     0
# 133194                                     0
# 133195                                     0
#
#         Pedestrian Crossing Tracks Injuries  \
# 246                                       0
# 247                                       0
# 248                                       0
# 122815                                    0
# 122816                                    0
# 122817                                    0
# 122818                                    0
# 125320                                    0
# 125321                                    0
# 125322                                    0
# 125817                                    0
# 125818                                    0
# 125819                                    0
# 125820                                    0
# 125821                                    0
# 125822                                    0
# 127275                                    0
# 127276                                    0
# 127278                                    0
# 127492                                    0
# 127493                                    0
# 127494                                    0
# 127495                                    0
# 127496                                    0
# 127497                                    0
# 127974                                    0
# 127975                                    0
# 127976                                    0
# 127977                                    0
# 127978                                    0
# 127979                                    0
# 127980                                    0
# 127981                                    0
# 127982                                    0
# 127983                                    0
# 127984                                    0
# 127985                                    0
# 131473                                    0
# 131474                                    0
# 132865                                    0
# 132866                                    0
# 132867                                    0
# 132868                                    0
# 133191                                    0
# 133192                                    0
# 133193                                    0
# 133194                                    0
# 133195                                    0
#
#         Pedestrian Walking Along Tracks Injuries  \
# 246                                            0
# 247                                            0
# 248                                            0
# 122815                                         0
# 122816                                         0
# 122817                                         0
# 122818                                         0
# 125320                                         0
# 125321                                         0
# 125322                                         0
# 125817                                         0
# 125818                                         0
# 125819                                         0
# 125820                                         0
# 125821                                         0
# 125822                                         0
# 127275                                         0
# 127276                                         0
# 127278                                         0
# 127492                                         0
# 127493                                         0
# 127494                                         0
# 127495                                         0
# 127496                                         0
# 127497                                         0
# 127974                                         0
# 127975                                         0
# 127976                                         0
# 127977                                         0
# 127978                                         0
# 127979                                         0
# 127980                                         0
# 127981                                         0
# 127982                                         0
# 127983                                         0
# 127984                                         0
# 127985                                         0
# 131473                                         0
# 131474                                         0
# 132865                                         0
# 132866                                         0
# 132867                                         0
# 132868                                         0
# 133191                                         0
# 133192                                         0
# 133193                                         0
# 133194                                         0
# 133195                                         0
#
#         Other Vehicle Occupant Injuries  Other Injuries  Trespasser Injuries  \
# 246                                   0               0                    0
# 247                                   0               0                    0
# 248                                   0               0                    0
# 122815                                0               0                    0
# 122816                                0               0                    0
# 122817                                0               0                    0
# 122818                                0               0                    0
# 125320                                1               0                    0
# 125321                                0               0                    0
# 125322                                0               0                    0
# 125817                                0               0                    0
# 125818                                0               0                    0
# 125819                                0               0                    0
# 125820                                0               0                    0
# 125821                                0               0                    0
# 125822                                0               0                    0
# 127275                                0               0                    0
# 127276                                1               0                    0
# 127278                                1               0                    0
# 127492                                0               0                    0
# 127493                                0               0                    0
# 127494                                0               0                    0
# 127495                                0               0                    0
# 127496                                0               0                    0
# 127497                                0               0                    0
# 127974                                0               0                    0
# 127975                                0               0                    0
# 127976                                0               0                    0
# 127977                                0               0                    0
# 127978                                0               0                    0
# 127979                                0               0                    0
# 127980                                0               0                    0
# 127981                                0               0                    0
# 127982                                0               0                    0
# 127983                                0               0                    0
# 127984                                0               0                    0
# 127985                                0               0                    0
# 131473                                0               0                    0
# 131474                                0               0                    0
# 132865                                2               0                    0
# 132866                                0               0                    0
# 132867                                0               0                    0
# 132868                                0               0                    0
# 133191                                0               0                    0
# 133192                                0               0                    0
# 133193                                0               0                    0
# 133194                                0               0                    0
# 133195                                0               0                    0
#
#         Suicide Injuries  Total Other Injuries  Total Injuries
# 246                    0                     0               0
# 247                    0                     0               0
# 248                    0                     0               0
# 122815                 0                     0               0
# 122816                 0                     0               0
# 122817                 0                     0               0
# 122818                 0                     0               0
# 125320                 0                     1               1
# 125321                 0                     0               0
# 125322                 0                     1               1
# 125817                 0                     0               0
# 125818                 0                     0               0
# 125819                 0                     0               0
# 125820                 0                     0               0
# 125821                 0                     0               0
# 125822                 0                     0               0
# 127275                 0                     0               0
# 127276                 0                     1               1
# 127278                 0                     3               3
# 127492                 0                     0               0
# 127493                 0                     0               0
# 127494                 0                     0               0
# 127495                 0                     0               0
# 127496                 0                     0               0
# 127497                 0                     0               0
# 127974                 0                     0               0
# 127975                 0                     0               0
# 127976                 0                     0               0
# 127977                 0                     0               0
# 127978                 0                     0               0
# 127979                 0                     0               0
# 127980                 0                     0               0
# 127981                 0                     0               0
# 127982                 0                     0               0
# 127983                 0                     0               0
# 127984                 0                     0               0
# 127985                 0                     0               0
# 131473                 0                     0               0
# 131474                 0                     0               0
# 132865                 0                     2               2
# 132866                 0                     0               7
# 132867                 0                     1               2
# 132868                 0                     0               0
# 133191                 0                     0               0
# 133192                 0                     0               0
# 133193                 0                     0               0
# 133194                 0                     0               0
# 133195                 0                     0               0
#
# [48 rows x 65 columns]

# %% [markdown]
# ##### 1.6.1.1.2 Removing the Rows of Data
# <a id='1.6.1.1.2_Removing_the_Rows_of_Data'></a>

# %%
data = data[data['Agency'].notna()]

# %% [markdown]
# Checking to make sure the data has been removed.

# %%
data[data['Agency'].isna()]
# Out:
# Empty DataFrame
# Columns: [5 DIgit NTD ID, 4 Digit NTD ID, Agency, Organization Type, Mode, Type of Service, Rail (Y/N), Primary UZA Code, Primary UZA Name, Primary UZA Sq Miles, Primary UZA Population, Service Area Sq Miles, Service Area Population, Year, Month, Vehicles, Vehicle Revenue Miles, Vehicle Revenue Hours, Ridership, Collisions with Motor Vehicle, Collisions with Person, Collisions with Fixed Object, Collisions with Rail Vehicle, Collisions with Bus Vehicle, Collisions with Other, Total Collisions, Total Derailments, Total Fires, Total Security Events, Total Events Not Otherwise Classified, Total Events, Passenger Fatalities, People Waiting or Leaving Fatalities, Operator Fatalities, Other Employee Fatalities, Total Employee Fatalities, Other Worker Fatalities, Bicyclist Fatalities, Pedestrian in Crosswalk Fatalities, Pedestrian Not in Crosswalk Fatalities, Pedestrian Crossing Tracks Fatalities, Pedestrian Walking Along Tracks Fatalities, Other Vehicle Occupant Fatalities, Other Fatalities, Trespasser Fatalities, Suicide Fatalities, Total Other Fatalities, Total Fatalities, Passenger Injuries, People Waiting or Leaving Injuries, Operator Injuries, Other Employee Injuries, Total Employee Injuries, Other Worker Injuries, Bicyclist Injuries, Pedestrian in Corsswalk Injuries, Pedestrian Not in Crosswalk Injuries, Pedestrian Crossing Tracks Injuries, Pedestrian Walking Along Tracks Injuries, Other Vehicle Occupant Injuries, Other Injuries, Trespasser Injuries, Suicide Injuries, Total Other Injuries, Total Injuries]
# Index: []
#
# [0 rows x 65 columns]

# %%
data[data['5 DIgit NTD ID']==r'"']
# Out:
# Empty DataFrame
# Columns: [5 DIgit NTD ID, 4 Digit NTD ID, Agency, Organization Type, Mode, Type of Service, Rail (Y/N), Primary UZA Code, Primary UZA Name, Primary UZA Sq Miles, Primary UZA Population, Service Area Sq Miles, Service Area Population, Year, Month, Vehicles, Vehicle Revenue Miles, Vehicle Revenue Hours, Ridership, Collisions with Motor Vehicle, Collisions with Person, Collisions with Fixed Object, Collisions with Rail Vehicle, Collisions with Bus Vehicle, Collisions with Other, Total Collisions, Total Derailments, Total Fires, Total Security Events, Total Events Not Otherwise Classified, Total Events, Passenger Fatalities, People Waiting or Leaving Fatalities, Operator Fatalities, Other Employee Fatalities, Total Employee Fatalities, Other Worker Fatalities, Bicyclist Fatalities, Pedestrian in Crosswalk Fatalities, Pedestrian Not in Crosswalk Fatalities, Pedestrian Crossing Tracks Fatalities, Pedestrian Walking Along Tracks Fatalities, Other Vehicle Occupant Fatalities, Other Fatalities, Trespasser Fatalities, Suicide Fatalities, Total Other Fatalities, Total Fatalities, Passenger Injuries, People Waiting or Leaving Injuries, Operator Injuries, Other Employee Injuries, Total Employee Injuries, Other Worker Injuries, Bicyclist Injuries, Pedestrian in Corsswalk Injuries, Pedestrian Not in Crosswalk Injuries, Pedestrian Crossing Tracks Injuries, Pedestrian Walking Along Tracks Injuries, Other Vehicle Occupant Injuries, Other Injuries, Trespasser Injuries, Suicide Injuries, Total Other Injuries, Total Injuries]
# Index: []
#
# [0 rows x 65 columns]

# %% [markdown]
# #### 1.6.1.2 Primary UZA Name, Sq Miles, and Population
# <a id='1.6.1.2_Primary_UZA_Name_Sq_Miles_and_Population'></a>

# %% [markdown]
# There are currently 4341 rows missing data for the 'Primary UZA Name', 'Primary UZA Sq Miles', and 'Primary UZA Population' columns.

# %%
data['Primary UZA Name'].isnull().sum()
# Out:
# 4341

# %%
data['Primary UZA Sq Miles'].isnull().sum()
# Out:
# 4341

# %%
data['Primary UZA Population'].isnull().sum()
# Out:
# 4341

# %% [markdown]
# ##### 1.6.1.2.1 Finding a Data Source
# <a id='1.6.1.2.1_Finding_a_Data_Source'></a>

# %% [markdown]
# There are 241 unique '5 DIgit NTD ID's where 'Primary UZA Name' is null.

# %%
dfisna = data[data['Primary UZA Name'].isnull()].sort_values('5 DIgit NTD ID')
dfisna['5 DIgit NTD ID'].nunique()
# Out:
# 241

# %% [markdown]
# Let's see how many of the '5 DIgit NTD ID's above have non-null data for 'Primary UZA Name' elsewhere in the dataframe.

# %%
# make another dataframe which contains unique 5 Digit IDs with Primary UZA Names (not NaN)

dfisnotna = data[data['Primary UZA Name'].notna()]
dfisnotna = dfisnotna[['5 DIgit NTD ID', 'Primary UZA Name']].drop_duplicates().sort_values('5 DIgit NTD ID')
dfisnotna
# Out:
#       5 DIgit NTD ID                    Primary UZA Name
# 9564           00001                         Seattle, WA
# 3874           00002                         Spokane, WA
# 4828           00003                         Seattle, WA
# 6770           00005                         Seattle, WA
# 7897           00006                          Yakima, WA
# ...              ...                                 ...
# 36810          91092                   Lake Tahoe, CA-NV
# 58760          99422                        Stockton, CA
# 28663          99423  Los Angeles-Long Beach-Anaheim, CA
# 61236          99424  Los Angeles-Long Beach-Anaheim, CA
# 29319          99425  Los Angeles-Long Beach-Anaheim, CA
#
# [610 rows x 2 columns]

# %%
# visualize the dataframe which contains unique 5 Digit IDs without Primary UZA Names (NaN)

dfisna = dfisna[['5 DIgit NTD ID', 'Primary UZA Name']].drop_duplicates().sort_values('5 DIgit NTD ID')
dfisna
# Out:
#        5 DIgit NTD ID Primary UZA Name
# 117267          00001              NaN
# 118081          00002              NaN
# 119722          00003              NaN
# 117746          00005              NaN
# 120585          00006              NaN
# ...               ...              ...
# 122497          80285              NaN
# 109772          90182              NaN
# 108439          90213              NaN
# 112699          90244              NaN
# 111828          99425              NaN
#
# [241 rows x 2 columns]

# %% [markdown]
# We can see that 240 of the 241 unique '5 DIgit NTD ID's appear both with and without 'Primary UZA Name's in the original dataframe.

# %%
#inner join dfisnotna and dfisna on 5 dig ID to see which/how many 5 dig IDs appear in both.

is_isnot = pd.merge(dfisnotna,dfisna, how='inner', on = '5 DIgit NTD ID')
is_isnot = is_isnot[['5 DIgit NTD ID']].drop_duplicates().sort_values('5 DIgit NTD ID')
is_isnot['5 DIgit NTD ID'].nunique()
# Out:
# 240

# %% [markdown]
# ##### 1.6.1.2.2 Filling the NaNs
# <a id='1.6.1.2.2_Filling_the_NaNs'></a>

# %% [markdown]
# The available data from the other rows in the dataframe will be used to fill the NaNs in the rows with missing data in the 'Primary UZA Name' column.
#
# Visualizing some of the missing data in these three fields for comparing before and after the NaNs are treated.

# %%
data[['5 DIgit NTD ID','Primary UZA Name', 'Primary UZA Sq Miles', 'Primary UZA Population']].sort_values('5 DIgit NTD ID').head(30)
# Out:
#        5 DIgit NTD ID Primary UZA Name  Primary UZA Sq Miles  \
# 72395           00001      Seattle, WA                1010.0
# 131493          00001      Seattle, WA                1010.0
# 131492          00001      Seattle, WA                1010.0
# 131491          00001      Seattle, WA                1010.0
# 131490          00001      Seattle, WA                1010.0
# 131489          00001      Seattle, WA                1010.0
# 131488          00001      Seattle, WA                1010.0
# 131487          00001      Seattle, WA                1010.0
# 131486          00001      Seattle, WA                1010.0
# 131485          00001      Seattle, WA                1010.0
# 131484          00001      Seattle, WA                1010.0
# 131483          00001      Seattle, WA                1010.0
# 9565            00001      Seattle, WA                1010.0
# 9564            00001      Seattle, WA                1010.0
# 131494          00001      Seattle, WA                1010.0
# 88850           00001      Seattle, WA                1010.0
# 88848           00001      Seattle, WA                1010.0
# 117236          00001              NaN                   NaN
# 117237          00001              NaN                   NaN
# 117238          00001              NaN                   NaN
# 117239          00001              NaN                   NaN
# 117240          00001              NaN                   NaN
# 117241          00001              NaN                   NaN
# 117242          00001              NaN                   NaN
# 117243          00001              NaN                   NaN
# 117244          00001              NaN                   NaN
# 117245          00001              NaN                   NaN
# 117246          00001              NaN                   NaN
# 117247          00001              NaN                   NaN
# 88849           00001      Seattle, WA                1010.0
#
#         Primary UZA Population
# 72395                3059393.0
# 131493               3059393.0
# 131492               3059393.0
# 131491               3059393.0
# 131490               3059393.0
# 131489               3059393.0
# 131488               3059393.0
# 131487               3059393.0
# 131486               3059393.0
# 131485               3059393.0
# 131484               3059393.0
# 131483               3059393.0
# 9565                 3059393.0
# 9564                 3059393.0
# 131494               3059393.0
# 88850                3059393.0
# 88848                3059393.0
# 117236                     NaN
# 117237                     NaN
# 117238                     NaN
# 117239                     NaN
# 117240                     NaN
# 117241                     NaN
# 117242                     NaN
# 117243                     NaN
# 117244                     NaN
# 117245                     NaN
# 117246                     NaN
# 117247                     NaN
# 88849                3059393.0

# %% [markdown]
# Treating the NaNs in 'Primary UZA Name' by filling with data found elsewhere in the dataframe where possible.

# %%
first = data.groupby('5 DIgit NTD ID')['Primary UZA Name'].first()
data['Primary UZA Name'] = data['Primary UZA Name'].fillna(data['5 DIgit NTD ID'].map(first))
data[['5 DIgit NTD ID','Primary UZA Name']].sort_values('5 DIgit NTD ID').head(30)
# Out:
#        5 DIgit NTD ID Primary UZA Name
# 72395           00001      Seattle, WA
# 131493          00001      Seattle, WA
# 131492          00001      Seattle, WA
# 131491          00001      Seattle, WA
# 131490          00001      Seattle, WA
# 131489          00001      Seattle, WA
# 131488          00001      Seattle, WA
# 131487          00001      Seattle, WA
# 131486          00001      Seattle, WA
# 131485          00001      Seattle, WA
# 131484          00001      Seattle, WA
# 131483          00001      Seattle, WA
# 9565            00001      Seattle, WA
# 9564            00001      Seattle, WA
# 131494          00001      Seattle, WA
# 88850           00001      Seattle, WA
# 88848           00001      Seattle, WA
# 117236          00001      Seattle, WA
# 117237          00001      Seattle, WA
# 117238          00001      Seattle, WA
# 117239          00001      Seattle, WA
# 117240          00001      Seattle, WA
# 117241          00001      Seattle, WA
# 117242          00001      Seattle, WA
# 117243          00001      Seattle, WA
# 117244          00001      Seattle, WA
# 117245          00001      Seattle, WA
# 117246          00001      Seattle, WA
# 117247          00001      Seattle, WA
# 88849           00001      Seattle, WA

# %% [markdown]
# Making sure the data filled correctly by looping through the grouped '5 DIgit NTD ID's to see if the first and last sorted 'Primary UZA Names' match.

# %%
df = data[['5 DIgit NTD ID', 'Primary UZA Name']]

# %%
min_i = df.groupby('5 DIgit NTD ID')['Primary UZA Name'].first()
min_i = pd.DataFrame(min_i)
min_i.head()
# Out:
#                Primary UZA Name
# 5 DIgit NTD ID
# 00001               Seattle, WA
# 00002               Spokane, WA
# 00003               Seattle, WA
# 00005               Seattle, WA
# 00006                Yakima, WA

# %%
max_i = df.groupby('5 DIgit NTD ID')['Primary UZA Name'].last()
max_i = pd.DataFrame(max_i)
max_i.head()
# Out:
#                Primary UZA Name
# 5 DIgit NTD ID
# 00001               Seattle, WA
# 00002               Spokane, WA
# 00003               Seattle, WA
# 00005               Seattle, WA
# 00006                Yakima, WA

# %%
df2 = min_i.merge(max_i, how='inner', on=('5 DIgit NTD ID'), suffixes=('_min', '_max'))
df2 = df2.replace({np.nan: None})
df2.head()
# Out:
#                Primary UZA Name_min Primary UZA Name_max
# 5 DIgit NTD ID
# 00001                   Seattle, WA          Seattle, WA
# 00002                   Spokane, WA          Spokane, WA
# 00003                   Seattle, WA          Seattle, WA
# 00005                   Seattle, WA          Seattle, WA
# 00006                    Yakima, WA           Yakima, WA

# %%
for x in range(len(df2)):
    if df2['Primary UZA Name_min'][x] != df2['Primary UZA Name_max'][x]:
        print('\nmin not equal to max for x =', x)
        print('5 DIgit NTD ID is:', df2.index[x])
        print('min is:', df2['Primary UZA Name_min'][x])
        print('max is:',df2['Primary UZA Name_max'][x])
# Out:
# min not equal to max for x = 124
# 5 DIgit NTD ID is: 20193
# min is: Philadelphia, PA-NJ-DE-MD
# max is: Vineland, NJ
#
# min not equal to max for x = 132
# 5 DIgit NTD ID is: 20223
# min is: Villas, NJ
# max is: Philadelphia, PA-NJ-DE-MD
#
# min not equal to max for x = 406
# 5 DIgit NTD ID is: 50522
# min is: Detroit, MI
# max is: Monroe, MI

# %% [markdown]
# Three '5 DIgit NTD ID's each have two 'Primary UZA Name's.  Confirming this below.

# %%
df2.loc[df2.index == '20193']
# Out:
#                      Primary UZA Name_min Primary UZA Name_max
# 5 DIgit NTD ID
# 20193           Philadelphia, PA-NJ-DE-MD         Vineland, NJ

# %%
df2.loc[df2.index == '20223']
# Out:
#                Primary UZA Name_min       Primary UZA Name_max
# 5 DIgit NTD ID
# 20223                    Villas, NJ  Philadelphia, PA-NJ-DE-MD

# %%
df2.loc[df2.index == '50522']
# Out:
#                Primary UZA Name_min Primary UZA Name_max
# 5 DIgit NTD ID
# 50522                   Detroit, MI           Monroe, MI

# %% [markdown]
# A count is taken of the number of occurrances of each 'Primary UZA Name' for the three '5 DIgit NTD ID's.

# %%
# https://www.transit.dot.gov/sites/fta.dot.gov/files/transit_agency_profile_doc/2021/20193.pdf

A = data.loc[data['5 DIgit NTD ID']=='20193']
A = A[['5 DIgit NTD ID', 'Primary UZA Name']]

B = data.loc[data['5 DIgit NTD ID']=='20223']
B = B[['5 DIgit NTD ID', 'Primary UZA Name']]

C = data.loc[data['5 DIgit NTD ID']=='50522']
C = C[['5 DIgit NTD ID', 'Primary UZA Name']]

plt.figure(figsize=(2,2))
_ = plt.hist(A['Primary UZA Name'], color='g')
_ = plt.xlabel('Primary UZA Names')
_ = plt.ylabel('Number of Rows')
_ = plt.title("Distribution of 'Primary UZA Names' for 20193")

plt.show()

plt.figure(figsize=(2,2))
_ = plt.hist(B['Primary UZA Name'], color='r')
_ = plt.xlabel('Primary UZA Names')
_ = plt.ylabel('Number of Rows')
_ = plt.title("Distribution of 'Primary UZA Names' for 20223")

plt.figure(figsize=(2,2))
_ = plt.hist(C['Primary UZA Name'], color='b')
_ = plt.xlabel('Primary UZA Names')
_ = plt.ylabel('Number of Rows')
_ = plt.title("Distribution of 'Primary UZA Names' for 50522")

# %% [markdown]
# Researching the FTA webiste confirms these are not errors.  The three '5 DIgit NTD ID's above which each have two different 'Primary UZA Names' serve and report for both as listed.  Documentation for each can be found at the links below:
#
# 20193: [Cumberland County](https://www.transit.dot.gov/sites/fta.dot.gov/files/transit_agency_profile_doc/2021/20193.pdf)
#
# 20223: [Cape May Lewes Ferry](https://www.transit.dot.gov/sites/fta.dot.gov/files/transit_agency_profile_doc/2021/20223.pdf)
#
# 50522: [Lake Erie Transportation Commission](https://www.transit.dot.gov/sites/fta.dot.gov/files/transit_agency_profile_doc/2021/50522.pdf)

# %% [markdown]
# Taking alook to see how many rows are still missing a 'Primary UZA Name'.

# %%
data['Primary UZA Name'].isnull().sum()
# Out:
# 27

# %% [markdown]
# The 27 rows which are still missing a 'Primary UZA Name' are all associated with the same '5 DIgit NTD ID'. This is the single '5 DIgit NTD ID' (out of the 241) that did not appear both with and without data in the dataframe.

# %%
dfisna = data[data['Primary UZA Name'].isnull()].sort_values('5 DIgit NTD ID')
dfisna
# Out:
#        5 DIgit NTD ID 4 Digit NTD ID  \
# 122949          70138       7R01-010
# 124519          70138       7R01-010
# 124518          70138       7R01-010
# 124517          70138       7R01-010
# 124516          70138       7R01-010
# 124515          70138       7R01-010
# 124514          70138       7R01-010
# 124513          70138       7R01-010
# 122966          70138       7R01-010
# 122965          70138       7R01-010
# 122964          70138       7R01-010
# 122963          70138       7R01-010
# 124520          70138       7R01-010
# 122962          70138       7R01-010
# 122960          70138       7R01-010
# 122959          70138       7R01-010
# 122958          70138       7R01-010
# 122957          70138       7R01-010
# 122956          70138       7R01-010
# 122955          70138       7R01-010
# 122954          70138       7R01-010
# 122953          70138       7R01-010
# 122952          70138       7R01-010
# 122951          70138       7R01-010
# 122950          70138       7R01-010
# 122961          70138       7R01-010
# 124521          70138       7R01-010
#
#                                           Agency Organization Type Mode  \
# 122949  East Central Iowa Council of Governments               NaN   VP
# 124519  East Central Iowa Council of Governments               NaN   DR
# 124518  East Central Iowa Council of Governments               NaN   DR
# 124517  East Central Iowa Council of Governments               NaN   DR
# 124516  East Central Iowa Council of Governments               NaN   DR
# 124515  East Central Iowa Council of Governments               NaN   DR
# 124514  East Central Iowa Council of Governments               NaN   DR
# 124513  East Central Iowa Council of Governments               NaN   DR
# 122966  East Central Iowa Council of Governments               NaN   CB
# 122965  East Central Iowa Council of Governments               NaN   CB
# 122964  East Central Iowa Council of Governments               NaN   CB
# 122963  East Central Iowa Council of Governments               NaN   CB
# 124520  East Central Iowa Council of Governments               NaN   DR
# 122962  East Central Iowa Council of Governments               NaN   CB
# 122960  East Central Iowa Council of Governments               NaN   CB
# 122959  East Central Iowa Council of Governments               NaN   CB
# 122958  East Central Iowa Council of Governments               NaN   CB
# 122957  East Central Iowa Council of Governments               NaN   VP
# 122956  East Central Iowa Council of Governments               NaN   VP
# 122955  East Central Iowa Council of Governments               NaN   VP
# 122954  East Central Iowa Council of Governments               NaN   VP
# 122953  East Central Iowa Council of Governments               NaN   VP
# 122952  East Central Iowa Council of Governments               NaN   VP
# 122951  East Central Iowa Council of Governments               NaN   VP
# 122950  East Central Iowa Council of Governments               NaN   VP
# 122961  East Central Iowa Council of Governments               NaN   CB
# 124521  East Central Iowa Council of Governments               NaN   DR
#
#        Type of Service Rail (Y/N)  Primary UZA Code Primary UZA Name  \
# 122949              PT      False                 0             None
# 124519              PT      False                 0             None
# 124518              PT      False                 0             None
# 124517              PT      False                 0             None
# 124516              PT      False                 0             None
# 124515              PT      False                 0             None
# 124514              PT      False                 0             None
# 124513              PT      False                 0             None
# 122966              PT      False                 0             None
# 122965              PT      False                 0             None
# 122964              PT      False                 0             None
# 122963              PT      False                 0             None
# 124520              PT      False                 0             None
# 122962              PT      False                 0             None
# 122960              PT      False                 0             None
# 122959              PT      False                 0             None
# 122958              PT      False                 0             None
# 122957              PT      False                 0             None
# 122956              PT      False                 0             None
# 122955              PT      False                 0             None
# 122954              PT      False                 0             None
# 122953              PT      False                 0             None
# 122952              PT      False                 0             None
# 122951              PT      False                 0             None
# 122950              PT      False                 0             None
# 122961              PT      False                 0             None
# 124521              PT      False                 0             None
#
#         Primary UZA Sq Miles  ...  Pedestrian in Corsswalk Injuries  \
# 122949                   NaN  ...                                 0
# 124519                   NaN  ...                                 0
# 124518                   NaN  ...                                 0
# 124517                   NaN  ...                                 0
# 124516                   NaN  ...                                 0
# 124515                   NaN  ...                                 0
# 124514                   NaN  ...                                 0
# 124513                   NaN  ...                                 0
# 122966                   NaN  ...                                 0
# 122965                   NaN  ...                                 0
# 122964                   NaN  ...                                 0
# 122963                   NaN  ...                                 0
# 124520                   NaN  ...                                 0
# 122962                   NaN  ...                                 0
# 122960                   NaN  ...                                 0
# 122959                   NaN  ...                                 0
# 122958                   NaN  ...                                 0
# 122957                   NaN  ...                                 0
# 122956                   NaN  ...                                 0
# 122955                   NaN  ...                                 0
# 122954                   NaN  ...                                 0
# 122953                   NaN  ...                                 0
# 122952                   NaN  ...                                 0
# 122951                   NaN  ...                                 0
# 122950                   NaN  ...                                 0
# 122961                   NaN  ...                                 0
# 124521                   NaN  ...                                 0
#
#         Pedestrian Not in Crosswalk Injuries  \
# 122949                                     0
# 124519                                     0
# 124518                                     0
# 124517                                     0
# 124516                                     0
# 124515                                     0
# 124514                                     0
# 124513                                     0
# 122966                                     0
# 122965                                     0
# 122964                                     0
# 122963                                     0
# 124520                                     0
# 122962                                     0
# 122960                                     0
# 122959                                     0
# 122958                                     0
# 122957                                     0
# 122956                                     0
# 122955                                     0
# 122954                                     0
# 122953                                     0
# 122952                                     0
# 122951                                     0
# 122950                                     0
# 122961                                     0
# 124521                                     0
#
#         Pedestrian Crossing Tracks Injuries  \
# 122949                                    0
# 124519                                    0
# 124518                                    0
# 124517                                    0
# 124516                                    0
# 124515                                    0
# 124514                                    0
# 124513                                    0
# 122966                                    0
# 122965                                    0
# 122964                                    0
# 122963                                    0
# 124520                                    0
# 122962                                    0
# 122960                                    0
# 122959                                    0
# 122958                                    0
# 122957                                    0
# 122956                                    0
# 122955                                    0
# 122954                                    0
# 122953                                    0
# 122952                                    0
# 122951                                    0
# 122950                                    0
# 122961                                    0
# 124521                                    0
#
#         Pedestrian Walking Along Tracks Injuries  \
# 122949                                         0
# 124519                                         0
# 124518                                         0
# 124517                                         0
# 124516                                         0
# 124515                                         0
# 124514                                         0
# 124513                                         0
# 122966                                         0
# 122965                                         0
# 122964                                         0
# 122963                                         0
# 124520                                         0
# 122962                                         0
# 122960                                         0
# 122959                                         0
# 122958                                         0
# 122957                                         0
# 122956                                         0
# 122955                                         0
# 122954                                         0
# 122953                                         0
# 122952                                         0
# 122951                                         0
# 122950                                         0
# 122961                                         0
# 124521                                         0
#
#         Other Vehicle Occupant Injuries  Other Injuries  Trespasser Injuries  \
# 122949                                0               0                    0
# 124519                                0               0                    0
# 124518                                0               0                    0
# 124517                                0               0                    0
# 124516                                0               0                    0
# 124515                                0               0                    0
# 124514                                0               0                    0
# 124513                                0               0                    0
# 122966                                0               0                    0
# 122965                                0               0                    0
# 122964                                0               0                    0
# 122963                                0               0                    0
# 124520                                0               0                    0
# 122962                                0               0                    0
# 122960                                0               0                    0
# 122959                                0               0                    0
# 122958                                0               0                    0
# 122957                                0               0                    0
# 122956                                0               0                    0
# 122955                                0               0                    0
# 122954                                0               0                    0
# 122953                                0               0                    0
# 122952                                0               0                    0
# 122951                                0               0                    0
# 122950                                0               0                    0
# 122961                                0               0                    0
# 124521                                0               0                    0
#
#         Suicide Injuries  Total Other Injuries  Total Injuries
# 122949                 0                     0               0
# 124519                 0                     0               0
# 124518                 0                     0               0
# 124517                 0                     0               0
# 124516                 0                     0               0
# 124515                 0                     0               0
# 124514                 0                     0               0
# 124513                 0                     0               0
# 122966                 0                     0               0
# 122965                 0                     0               0
# 122964                 0                     0               0
# 122963                 0                     0               0
# 124520                 0                     0               0
# 122962                 0                     0               0
# 122960                 0                     0               0
# 122959                 0                     0               0
# 122958                 0                     0               0
# 122957                 0                     0               0
# 122956                 0                     0               0
# 122955                 0                     0               0
# 122954                 0                     0               0
# 122953                 0                     0               0
# 122952                 0                     0               0
# 122951                 0                     0               0
# 122950                 0                     0               0
# 122961                 0                     0               0
# 124521                 0                     0               0
#
# [27 rows x 65 columns]

# %% [markdown]
# The original dataframe contains 27 rows of data from The East Central Iowa Council of Governments, but none of those rows of data contain information for the 'Primary UZA Name'.  Consequently, it will not be possible to fill those NaNs.
#
# Additionally, there is no data in the dataframe for 'Primary UZA Sq Miles' or 'Primary UZA Population' so 27 rows of missing data will remain after treating the other NaNs in those two columns.
#
# Further, the same issue will arrive in the next section of the notebook when treating the NaNs in 'Organization Type', 'Service Area Sq Miles', and 'Service Area Population'.

# %%
data[data['5 DIgit NTD ID']=='70138'].notnull().sum()
# Out:
# 5 DIgit NTD ID                                27
# 4 Digit NTD ID                                27
# Agency                                        27
# Organization Type                              0
# Mode                                          27
# Type of Service                               27
# Rail (Y/N)                                    27
# Primary UZA Code                              27
# Primary UZA Name                               0
# Primary UZA Sq Miles                           0
# Primary UZA Population                         0
# Service Area Sq Miles                          0
# Service Area Population                        0
# Year                                          27
# Month                                         27
# Vehicles                                      27
# Vehicle Revenue Miles                         27
# Vehicle Revenue Hours                         27
# Ridership                                     27
# Collisions with Motor Vehicle                 27
# Collisions with Person                        27
# Collisions with Fixed Object                  27
# Collisions with Rail Vehicle                  27
# Collisions with Bus Vehicle                   27
# Collisions with Other                         27
# Total Collisions                              27
# Total Derailments                             27
# Total Fires                                   27
# Total Security Events                         27
# Total Events Not Otherwise Classified         27
# Total Events                                  27
# Passenger Fatalities                          27
# People Waiting or Leaving Fatalities          27
# Operator Fatalities                           27
# Other Employee Fatalities                     27
# Total Employee Fatalities                     27
# Other Worker Fatalities                       27
# Bicyclist Fatalities                          27
# Pedestrian in Crosswalk Fatalities            27
# Pedestrian Not in Crosswalk Fatalities        27
# Pedestrian Crossing Tracks Fatalities         27
# Pedestrian Walking Along Tracks Fatalities    27
# Other Vehicle Occupant Fatalities             27
# Other Fatalities                              27
# Trespasser Fatalities                         27
# Suicide Fatalities                            27
# Total Other Fatalities                        27
# Total Fatalities                              27
# Passenger Injuries                            27
# People Waiting or Leaving Injuries            27
# Operator Injuries                             27
# Other Employee Injuries                       27
# Total Employee Injuries                       27
# Other Worker Injuries                         27
# Bicyclist Injuries                            27
# Pedestrian in Corsswalk Injuries              27
# Pedestrian Not in Crosswalk Injuries          27
# Pedestrian Crossing Tracks Injuries           27
# Pedestrian Walking Along Tracks Injuries      27
# Other Vehicle Occupant Injuries               27
# Other Injuries                                27
# Trespasser Injuries                           27
# Suicide Injuries                              27
# Total Other Injuries                          27
# Total Injuries                                27
# dtype: int64

# %% [markdown]
# Treating the NaNs in 'Primary UZA Sq Miles' by filling with data found elsewhere in the dataframe where possible.

# %%
first = data.groupby('5 DIgit NTD ID')['Primary UZA Sq Miles'].first()
data['Primary UZA Sq Miles'] = data['Primary UZA Sq Miles'].fillna(data['5 DIgit NTD ID'].map(first))

# %%
data['Primary UZA Sq Miles'].isnull().sum()
# Out:
# 27

# %% [markdown]
# Treating the NaNs in 'Primary UZA Population' by filling with data found elsewhere in the dataframe where possible.

# %%
first = data.groupby('5 DIgit NTD ID')['Primary UZA Population'].first()
data['Primary UZA Population'] = data['Primary UZA Population'].fillna(data['5 DIgit NTD ID'].map(first))

# %%
data['Primary UZA Population'].isnull().sum()
# Out:
# 27

# %% [markdown]
# Visualizing the same snapshot of data from the beginning of this section now that the NaNs have been treated.

# %%
data[['5 DIgit NTD ID','Primary UZA Name', 'Primary UZA Sq Miles', 'Primary UZA Population']].sort_values('5 DIgit NTD ID').head(30)
# Out:
#        5 DIgit NTD ID Primary UZA Name  Primary UZA Sq Miles  \
# 72395           00001      Seattle, WA                1010.0
# 131493          00001      Seattle, WA                1010.0
# 131492          00001      Seattle, WA                1010.0
# 131491          00001      Seattle, WA                1010.0
# 131490          00001      Seattle, WA                1010.0
# 131489          00001      Seattle, WA                1010.0
# 131488          00001      Seattle, WA                1010.0
# 131487          00001      Seattle, WA                1010.0
# 131486          00001      Seattle, WA                1010.0
# 131485          00001      Seattle, WA                1010.0
# 131484          00001      Seattle, WA                1010.0
# 131483          00001      Seattle, WA                1010.0
# 9565            00001      Seattle, WA                1010.0
# 9564            00001      Seattle, WA                1010.0
# 131494          00001      Seattle, WA                1010.0
# 88850           00001      Seattle, WA                1010.0
# 88848           00001      Seattle, WA                1010.0
# 117236          00001      Seattle, WA                1010.0
# 117237          00001      Seattle, WA                1010.0
# 117238          00001      Seattle, WA                1010.0
# 117239          00001      Seattle, WA                1010.0
# 117240          00001      Seattle, WA                1010.0
# 117241          00001      Seattle, WA                1010.0
# 117242          00001      Seattle, WA                1010.0
# 117243          00001      Seattle, WA                1010.0
# 117244          00001      Seattle, WA                1010.0
# 117245          00001      Seattle, WA                1010.0
# 117246          00001      Seattle, WA                1010.0
# 117247          00001      Seattle, WA                1010.0
# 88849           00001      Seattle, WA                1010.0
#
#         Primary UZA Population
# 72395                3059393.0
# 131493               3059393.0
# 131492               3059393.0
# 131491               3059393.0
# 131490               3059393.0
# 131489               3059393.0
# 131488               3059393.0
# 131487               3059393.0
# 131486               3059393.0
# 131485               3059393.0
# 131484               3059393.0
# 131483               3059393.0
# 9565                 3059393.0
# 9564                 3059393.0
# 131494               3059393.0
# 88850                3059393.0
# 88848                3059393.0
# 117236               3059393.0
# 117237               3059393.0
# 117238               3059393.0
# 117239               3059393.0
# 117240               3059393.0
# 117241               3059393.0
# 117242               3059393.0
# 117243               3059393.0
# 117244               3059393.0
# 117245               3059393.0
# 117246               3059393.0
# 117247               3059393.0
# 88849                3059393.0

# %% [markdown]
# #### 1.6.1.3 Organization Type, Service Sq Miles, and Service Area Population
# <a id='1.6.1.3_Organization_Type_Service_Sq_Miles_and_Service_Area_Population'></a>

# %% [markdown]
# There are currently thousands of rows of missing data for 'Organization Type', 'Service Area Sq Miles', and 'Service Area Population'.

# %%
data['Organization Type'].isnull().sum()
# Out:
# 4329

# %%
data['Service Area Sq Miles'].isnull().sum()
# Out:
# 4236

# %%
data['Service Area Population'].isnull().sum()
# Out:
# 4236

# %% [markdown]
# Visualizing some of the missing data in these three fields for comparing before and after the NaNs are treated.

# %%
data[['5 DIgit NTD ID','Organization Type', 'Service Area Sq Miles', 'Service Area Population']].sort_values('5 DIgit NTD ID').head(30)
# Out:
#        5 DIgit NTD ID                                  Organization Type  \
# 72395           00001  City, County or Local Government Unit or Depar...
# 131493          00001  City, County or Local Government Unit or Depar...
# 131492          00001  City, County or Local Government Unit or Depar...
# 131491          00001  City, County or Local Government Unit or Depar...
# 131490          00001  City, County or Local Government Unit or Depar...
# 131489          00001  City, County or Local Government Unit or Depar...
# 131488          00001  City, County or Local Government Unit or Depar...
# 131487          00001  City, County or Local Government Unit or Depar...
# 131486          00001  City, County or Local Government Unit or Depar...
# 131485          00001  City, County or Local Government Unit or Depar...
# 131484          00001  City, County or Local Government Unit or Depar...
# 131483          00001  City, County or Local Government Unit or Depar...
# 9565            00001  City, County or Local Government Unit or Depar...
# 9564            00001  City, County or Local Government Unit or Depar...
# 131494          00001  City, County or Local Government Unit or Depar...
# 88850           00001  City, County or Local Government Unit or Depar...
# 88848           00001  City, County or Local Government Unit or Depar...
# 117236          00001                                                NaN
# 117237          00001                                                NaN
# 117238          00001                                                NaN
# 117239          00001                                                NaN
# 117240          00001                                                NaN
# 117241          00001                                                NaN
# 117242          00001                                                NaN
# 117243          00001                                                NaN
# 117244          00001                                                NaN
# 117245          00001                                                NaN
# 117246          00001                                                NaN
# 117247          00001                                                NaN
# 88849           00001  City, County or Local Government Unit or Depar...
#
#         Service Area Sq Miles  Service Area Population
# 72395                  2134.0                2149970.0
# 131493                 2134.0                2287050.0
# 131492                 2134.0                2287050.0
# 131491                 2134.0                2287050.0
# 131490                 2134.0                2287050.0
# 131489                 2134.0                2287050.0
# 131488                 2134.0                2287050.0
# 131487                 2134.0                2287050.0
# 131486                 2134.0                2287050.0
# 131485                 2134.0                2287050.0
# 131484                 2134.0                2287050.0
# 131483                 2134.0                2287050.0
# 9565                   2134.0                2017250.0
# 9564                   2134.0                2017250.0
# 131494                 2134.0                2287050.0
# 88850                  2134.0                2149970.0
# 88848                  2134.0                2149970.0
# 117236                    NaN                      NaN
# 117237                    NaN                      NaN
# 117238                    NaN                      NaN
# 117239                    NaN                      NaN
# 117240                    NaN                      NaN
# 117241                    NaN                      NaN
# 117242                    NaN                      NaN
# 117243                    NaN                      NaN
# 117244                    NaN                      NaN
# 117245                    NaN                      NaN
# 117246                    NaN                      NaN
# 117247                    NaN                      NaN
# 88849                  2134.0                2149970.0

# %% [markdown]
# Treating the NaNs in the three fields by filling with data found elsewhere in the dataframe where possible.

# %%
first = data.groupby('5 DIgit NTD ID')['Organization Type'].first()
data['Organization Type'] = data['Organization Type'].fillna(data['5 DIgit NTD ID'].map(first))

# %%
first = data.groupby('5 DIgit NTD ID')['Service Area Sq Miles'].first()
data['Service Area Sq Miles'] = data['Service Area Sq Miles'].fillna(data['5 DIgit NTD ID'].map(first))

# %%
first = data.groupby('5 DIgit NTD ID')['Service Area Population'].first()
data['Service Area Population'] = data['Service Area Population'].fillna(data['5 DIgit NTD ID'].map(first))

# %% [markdown]
# Visualizing the same snapshot of data after the NaNs have been treated.

# %%
data[['5 DIgit NTD ID','Organization Type', 'Service Area Sq Miles', 'Service Area Population']].sort_values('5 DIgit NTD ID').head(30)
# Out:
#        5 DIgit NTD ID                                  Organization Type  \
# 72395           00001  City, County or Local Government Unit or Depar...
# 131493          00001  City, County or Local Government Unit or Depar...
# 131492          00001  City, County or Local Government Unit or Depar...
# 131491          00001  City, County or Local Government Unit or Depar...
# 131490          00001  City, County or Local Government Unit or Depar...
# 131489          00001  City, County or Local Government Unit or Depar...
# 131488          00001  City, County or Local Government Unit or Depar...
# 131487          00001  City, County or Local Government Unit or Depar...
# 131486          00001  City, County or Local Government Unit or Depar...
# 131485          00001  City, County or Local Government Unit or Depar...
# 131484          00001  City, County or Local Government Unit or Depar...
# 131483          00001  City, County or Local Government Unit or Depar...
# 9565            00001  City, County or Local Government Unit or Depar...
# 9564            00001  City, County or Local Government Unit or Depar...
# 131494          00001  City, County or Local Government Unit or Depar...
# 88850           00001  City, County or Local Government Unit or Depar...
# 88848           00001  City, County or Local Government Unit or Depar...
# 117236          00001  City, County or Local Government Unit or Depar...
# 117237          00001  City, County or Local Government Unit or Depar...
# 117238          00001  City, County or Local Government Unit or Depar...
# 117239          00001  City, County or Local Government Unit or Depar...
# 117240          00001  City, County or Local Government Unit or Depar...
# 117241          00001  City, County or Local Government Unit or Depar...
# 117242          00001  City, County or Local Government Unit or Depar...
# 117243          00001  City, County or Local Government Unit or Depar...
# 117244          00001  City, County or Local Government Unit or Depar...
# 117245          00001  City, County or Local Government Unit or Depar...
# 117246          00001  City, County or Local Government Unit or Depar...
# 117247          00001  City, County or Local Government Unit or Depar...
# 88849           00001  City, County or Local Government Unit or Depar...
#
#         Service Area Sq Miles  Service Area Population
# 72395                  2134.0                2149970.0
# 131493                 2134.0                2287050.0
# 131492                 2134.0                2287050.0
# 131491                 2134.0                2287050.0
# 131490                 2134.0                2287050.0
# 131489                 2134.0                2287050.0
# 131488                 2134.0                2287050.0
# 131487                 2134.0                2287050.0
# 131486                 2134.0                2287050.0
# 131485                 2134.0                2287050.0
# 131484                 2134.0                2287050.0
# 131483                 2134.0                2287050.0
# 9565                   2134.0                2017250.0
# 9564                   2134.0                2017250.0
# 131494                 2134.0                2287050.0
# 88850                  2134.0                2149970.0
# 88848                  2134.0                2149970.0
# 117236                 2134.0                2017250.0
# 117237                 2134.0                2017250.0
# 117238                 2134.0                2017250.0
# 117239                 2134.0                2017250.0
# 117240                 2134.0                2017250.0
# 117241                 2134.0                2017250.0
# 117242                 2134.0                2017250.0
# 117243                 2134.0                2017250.0
# 117244                 2134.0                2017250.0
# 117245                 2134.0                2017250.0
# 117246                 2134.0                2017250.0
# 117247                 2134.0                2017250.0
# 88849                  2134.0                2149970.0

# %%
data['Organization Type'].isnull().sum()
# Out:
# 27

# %%
data['Service Area Sq Miles'].isnull().sum()
# Out:
# 27

# %%
data['Service Area Population'].isnull().sum()
# Out:
# 27

# %% [markdown]
# Revisiting the graphic from the beginning of this section to show the progress made toward reducing the amount of missing data in the dataframe.

# %%
missingpercent = (100 * data.isnull().mean())

plt.figure(figsize=(16,22))
ax = missingpercent.sort_values(ascending=True).plot(kind='barh', fontsize=14)
ax.set_title('Percentage of Data Missing from Columns in NTD', fontsize=30, pad=20)
ax.set_xlabel('Percentage', fontsize=20)
ax.set_ylabel('Column Name', fontsize=20)


# Function below adapted from (https://stackoverflow.com/questions/28931224/how-to-add-value-labels-on-a-bar-chart)

def add_value_labels(ax, spacing=5):
    """Add labels to the end of each bar in a bar chart."""

# For each bar: Place a label
for rect in ax.patches:
    # Get X and Y placement of label from rect
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2

    # Number of points between bar and label
    space = 5
    # Vertical alignment for positive values
    ha = 'left'

    # Use X value as label and format number with three decimal places
    label = "{:.3f}".format(x_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(space, 0),          # Horizontally shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        va='center',                # Vertically center label
        ha=ha)                      # Horizontally align label differently for
                                    # positive and negative values.

# Call the function
add_value_labels(ax)

# %%
data.shape
# Out:
# (133148, 65)

# %% [markdown]
# ### 1.6.2 Determining the Primary Identifier
# <a id='1.6.2_Determining_the_Primary_Identifier'></a>
#
# The '5 DIgit NTD ID', '4 Digit NTD ID', and 'Agency' columns contain unique identifying information for each reporting agency.  All three should be explored to determine which should be used as a primary identifier, and whether both or just one of the ID column should be preserved in the database.

# %% [markdown]
# The number of unique values in the '5 DIgit NTD ID' column is greater than the number of unique values in the '4 Digit NTD ID' column which makes sence since the FTA refers to the '4 Digit NTD ID' as the legacy ID.
# The number of unique  values in "5 DIgit NTD ID" and "Agency" are pretty close.

# %%
data['5 DIgit NTD ID'].nunique()
# Out:
# 608

# %%
data['4 Digit NTD ID'].nunique()
# Out:
# 571

# %%
data['Agency'].nunique()
# Out:
# 607

# %% [markdown]
# #### 1.6.2.1 Comparing '5 DIgit NTD ID' and '4 Digit NTD ID'
# <a id='1.6.2.1_Comparing_5_DIgit_NTD_ID_and_4_Digit_NTD_ID'></a>

# %% [markdown]
# There are 37 more unique '5 DIgit NTD ID's than '4 Digit NTD ID's in the dataframe.  This section will look at those 37 rows to see if a pattern emerges or if a reason can be inferred for the discrepancy.

# %%
#separating out the unique five digit IDs

five_unique = data[['5 DIgit NTD ID']].drop_duplicates().sort_values('5 DIgit NTD ID')
five_unique
# Out:
#       5 DIgit NTD ID
# 9564           00001
# 3874           00002
# 4828           00003
# 6770           00005
# 7897           00006
# ...              ...
# 36810          91092
# 58760          99422
# 28663          99423
# 61236          99424
# 29319          99425
#
# [608 rows x 1 columns]

# %%
#separating out the unique four digit IDs

four_unique = data[['4 Digit NTD ID']].drop_duplicates().sort_values('4 Digit NTD ID')
four_unique
# Out:
#       4 Digit NTD ID
# 9564            0001
# 3874            0002
# 4828            0003
# 6770            0005
# 7897            0006
# ...              ...
# 6571            9242
# 10821           9244
# 29295           9296
# 36810       9R02-137
# 11512            NaN
#
# [572 rows x 1 columns]

# %% [markdown]
# There are 2997 rows of data for the 37 reporting agencies which have a '5 DIgit NTD ID' but no '4 Digit NTD ID'.  Looking at a subset of columns split into two sections will help with readability.  The columns with the numbers of accidents, injuries, and fatalities are not needed in this section.

# %%
five_not_four = data[data['4 Digit NTD ID'].isna()].sort_values(['5 DIgit NTD ID', 'Year'])
five_not_four_set1 = five_not_four[['5 DIgit NTD ID', '4 Digit NTD ID','Agency', 'Organization Type', 'Mode', 'Type of Service', 'Rail (Y/N)']].sort_values(['5 DIgit NTD ID'])
five_not_four_set1.shape
# Out:
# (2997, 7)

# %%
five_not_four = data[data['4 Digit NTD ID'].isna()].sort_values(['5 DIgit NTD ID', 'Year'])
five_not_four_set2 = five_not_four[['5 DIgit NTD ID', '4 Digit NTD ID','Primary UZA Code', 'Primary UZA Name', 'Primary UZA Sq Miles', 'Primary UZA Population', 'Service Area Sq Miles', 'Service Area Population', 'Year']].sort_values(['5 DIgit NTD ID'])
five_not_four_set2.shape
# Out:
# (2997, 9)

# %%
five_not_four_Agency_count = five_not_four['Agency'].nunique()
five_not_four_Agency_count
# Out:
# 37

# %% [markdown]
# Looking at one row for each of the 37 '5 DIgit NTD ID's which do not have '4 Digit NTD ID's.

# %%
five_not_four_set1 = five_not_four_set1.drop_duplicates(subset='5 DIgit NTD ID', keep="first")
five_not_four_set1
# Out:
#        5 DIgit NTD ID 4 Digit NTD ID  \
# 49378           00415            NaN
# 71137           10183            NaN
# 115275          11147            NaN
# 131166          11238            NaN
# 97326           11239            NaN
# 133143          20223            NaN
# 133175          20226            NaN
# 95378           22930            NaN
# 96923           30201            NaN
# 90147           30202            NaN
# 94360           40244            NaN
# 57469           40245            NaN
# 77705           40247            NaN
# 75458           40258            NaN
# 55092           40259            NaN
# 95906           40264            NaN
# 122939          40265            NaN
# 127833          41199            NaN
# 126103          42000            NaN
# 96816           44929            NaN
# 102900          50521            NaN
# 91726           50522            NaN
# 118041          55311            NaN
# 131209          55312            NaN
# 120566          60269            NaN
# 120011          66339            NaN
# 89201           70044            NaN
# 118358          70271            NaN
# 121207          70275            NaN
# 120580          90094            NaN
# 110296          90299            NaN
# 117761          90302            NaN
# 112490          90306            NaN
# 112063          99422            NaN
# 90035           99423            NaN
# 116353          99424            NaN
# 91988           99425            NaN
#
#                                                    Agency  \
# 49378                         Ada County Highway District
# 71137   Woods Hole, Martha's Vineyard and Nantucket St...
# 115275          Rhode Island Department of Transportation
# 131166                           Bay State Cruise Company
# 97326                          Hyannis Harbor Tours, Inc.
# 133143                               Cape May Lewes Ferry
# 133175                                     SeaStreak, LLC
# 95378      New York City Economic Development Corporation
# 96923                                   City of Baltimore
# 90147                     South Central Transit Authority
# 94360          Spartanburg Regional Health Services, Inc.
# 57469                  Clay County Council on Aging, Inc.
# 77705                            Shelby County Government
# 75458                              The Looper Group, Inc.
# 55092   Jolley Trolley Transportation of Clearwater, Inc.
# 95906            Georgia State Road and Tollway Authority
# 122939  North Central Alabama Regional Council of Gove...
# 127833  Board of County Commissioners of St. Lucie County
# 126103              Atlanta-Region Transit Link Authority
# 96816                             City of Fort Lauderdale
# 102900                      Chicago Water Taxi (Wendella)
# 91726                 Lake Erie Transportation Commission
# 118041                                 City of Cincinnati
# 131209                                  City of Milwaukee
# 120566                             Texas State University
# 120011            New Mexico Department of Transportation
# 89201                                University of Kansas
# 118358                      Kansas City, City of Missouri
# 121207              Nebraska Department of Transportation
# 120580             Metropolitan Transportation Commission
# 110296            Sonoma-Marin Area Rail Transit District
# 117761     San Bernardino County Transportation Authority
# 112490              Stanislaus Regional Transit Authority
# 112063                                San Joaquin Council
# 90035                                    City of Glendale
# 116353                                   City of Pasadena
# 91988              Pomona Valley Transportation Authority
#
#                                         Organization Type Mode  \
# 49378   City, County or Local Government Unit or Depar...   VP
# 71137   Independent Public Agency or Authority of Tran...   MB
# 115275  State Government Unit or Department of Transpo...   FB
# 131166                     Private-For-Profit Corporation   FB
# 97326                      Private-For-Profit Corporation   FB
# 133143  Independent Public Agency or Authority of Tran...   FB
# 133175                     Private-For-Profit Corporation   FB
# 95378                      Private-Non-Profit Corporation   MB
# 96923   City, County or Local Government Unit or Depar...   MB
# 90147   Independent Public Agency or Authority of Tran...   DR
# 94360   State Government Unit or Department of Transpo...   DR
# 57469                      Private-Non-Profit Corporation   DR
# 77705   City, County or Local Government Unit or Depar...   VP
# 75458                      Private-Non-Profit Corporation   MB
# 55092                      Private-Non-Profit Corporation   MB
# 95906   State Government Unit or Department of Transpo...   CB
# 122939                  MPO, COG or Other Planning Agency   DR
# 127833  City, County or Local Government Unit or Depar...   DR
# 126103  State Government Unit or Department of Transpo...   CB
# 96816   City, County or Local Government Unit or Depar...   FB
# 102900                     Private-For-Profit Corporation   FB
# 91726   Independent Public Agency or Authority of Tran...   DR
# 118041  City, County or Local Government Unit or Depar...   SR
# 131209  City, County or Local Government Unit or Depar...   SR
# 120566                                         University   MB
# 120011  State Government Unit or Department of Transpo...   VP
# 89201                                          University   MB
# 118358  City, County or Local Government Unit or Depar...   SR
# 121207  State Government Unit or Department of Transpo...   VP
# 120580                  MPO, COG or Other Planning Agency   VP
# 110296  Independent Public Agency or Authority of Tran...   CR
# 117761                  MPO, COG or Other Planning Agency   VP
# 112490  Independent Public Agency or Authority of Tran...   MB
# 112063                  MPO, COG or Other Planning Agency   VP
# 90035   City, County or Local Government Unit or Depar...   DR
# 116353  City, County or Local Government Unit or Depar...   MB
# 91988   Independent Public Agency or Authority of Tran...   DR
#
#        Type of Service Rail (Y/N)
# 49378               DO      False
# 71137               DO      False
# 115275              PT      False
# 131166              DO      False
# 97326               DO      False
# 133143              DO      False
# 133175              DO      False
# 95378               PT      False
# 96923               PT      False
# 90147               PT      False
# 94360               DO      False
# 57469               DO      False
# 77705               PT      False
# 75458               DO      False
# 55092               DO      False
# 95906               PT      False
# 122939              DO      False
# 127833              PT      False
# 126103              PT      False
# 96816               PT      False
# 102900              DO      False
# 91726               DO      False
# 118041              PT       True
# 131209              PT       True
# 120566              PT      False
# 120011              PT      False
# 89201               PT      False
# 118358              PT       True
# 121207              PT      False
# 120580              PT      False
# 110296              DO       True
# 117761              PT      False
# 112490              PT      False
# 112063              PT      False
# 90035               PT      False
# 116353              PT      False
# 91988               TX      False

# %%
five_not_four_set2 = five_not_four_set2.drop_duplicates(subset='5 DIgit NTD ID', keep="first")
five_not_four_set2
# Out:
#        5 DIgit NTD ID 4 Digit NTD ID  Primary UZA Code  \
# 49378           00415            NaN               108
# 71137           10183            NaN               152
# 115275          11147            NaN                39
# 131166          11238            NaN               152
# 97326           11239            NaN               152
# 133143          20223            NaN                 5
# 133175          20226            NaN                 1
# 95378           22930            NaN                 1
# 96923           30201            NaN                19
# 90147           30202            NaN                91
# 94360           40244            NaN               192
# 57469           40245            NaN                40
# 77705           40247            NaN                41
# 75458           40258            NaN                17
# 55092           40259            NaN                17
# 95906           40264            NaN                 9
# 122939          40265            NaN               392
# 127833          41199            NaN               101
# 126103          42000            NaN                 9
# 96816           44929            NaN                 4
# 102900          50521            NaN                 3
# 91726           50522            NaN               490
# 118041          55311            NaN                30
# 131209          55312            NaN                35
# 120566          60269            NaN               479
# 120011          66339            NaN               250
# 89201           70044            NaN               332
# 118358          70271            NaN                31
# 121207          70275            NaN                58
# 120580          90094            NaN                13
# 110296          90299            NaN               123
# 117761          90302            NaN                22
# 112490          90306            NaN               105
# 112063          99422            NaN               102
# 90035           99423            NaN                 2
# 116353          99424            NaN                 2
# 91988           99425            NaN                 2
#
#                           Primary UZA Name  Primary UZA Sq Miles  \
# 49378                       Boise City, ID                 134.0
# 71137                  Barnstable Town, MA                 277.0
# 115275                   Providence, RI-MA                 545.0
# 131166                 Barnstable Town, MA                 277.0
# 97326                  Barnstable Town, MA                 277.0
# 133143           Philadelphia, PA-NJ-DE-MD                1981.0
# 133175           New York-Newark, NY-NJ-CT                3450.0
# 95378            New York-Newark, NY-NJ-CT                3450.0
# 96923                        Baltimore, MD                 717.0
# 90147                        Lancaster, PA                 248.0
# 94360                      Spartanburg, SC                 190.0
# 57469                     Jacksonville, FL                 530.0
# 77705                    Memphis, TN-MS-AR                 497.0
# 75458             Tampa-St. Petersburg, FL                 957.0
# 55092             Tampa-St. Petersburg, FL                 957.0
# 95906                          Atlanta, GA                2645.0
# 122939                         Decatur, AL                  58.0
# 127833                  Port St. Lucie, FL                 208.0
# 126103                         Atlanta, GA                2645.0
# 96816                            Miami, FL                1239.0
# 102900                      Chicago, IL-IN                2443.0
# 91726                           Monroe, MI                  32.0
# 118041                Cincinnati, OH-KY-IN                 788.0
# 131209                       Milwaukee, WI                 546.0
# 120566                      San Marcos, TX                  27.0
# 120011                      Las Cruces, NM                  65.0
# 89201                         Lawrence, KS                  30.0
# 118358                  Kansas City, MO-KS                 678.0
# 121207                        Omaha, NE-IA                 271.0
# 120580           San Francisco-Oakland, CA                 524.0
# 110296                      Santa Rosa, CA                  98.0
# 117761        Riverside-San Bernardino, CA                 545.0
# 112490                         Modesto, CA                  92.0
# 112063                        Stockton, CA                  93.0
# 90035   Los Angeles-Long Beach-Anaheim, CA                1736.0
# 116353  Los Angeles-Long Beach-Anaheim, CA                1736.0
# 91988   Los Angeles-Long Beach-Anaheim, CA                1736.0
#
#         Primary UZA Population  Service Area Sq Miles  \
# 49378                 349684.0                15134.0
# 71137                 246695.0                 2100.0
# 115275               1190956.0                   10.0
# 131166                246695.0                  277.0
# 97326                 246695.0                  394.0
# 133143               5441567.0                 1187.0
# 133175              18351295.0                  776.0
# 95378               18351295.0                   37.0
# 96923                2203663.0                   81.0
# 90147                 402004.0                 1848.0
# 94360                 180786.0                  811.0
# 57469                1065219.0                  881.0
# 77705                1060061.0                  319.0
# 75458                2441770.0                    3.0
# 55092                2441770.0                   21.0
# 95906                4515419.0                  498.0
# 122939                 70436.0                 1316.0
# 127833                376047.0                  572.0
# 126103               4515419.0                  498.0
# 96816                5502379.0                   17.0
# 102900               8608208.0                   89.0
# 91726                  51240.0                  153.0
# 118041               1624827.0                    3.0
# 131209               1376476.0                    1.0
# 120566                 52826.0                   23.0
# 120011                128600.0                 1520.0
# 89201                  88053.0                   15.0
# 118358               1519417.0                    2.0
# 121207                725008.0                  252.0
# 120580               3281212.0                 6900.0
# 110296                308231.0                 2596.0
# 117761               1932666.0                 2953.0
# 112490                358172.0                 1515.0
# 112063                370583.0                 1426.0
# 90035               12150996.0                   39.0
# 116353              12150996.0                   23.0
# 91988               12150996.0                   61.0
#
#         Service Area Population  Year
# 49378                  814966.0  2016
# 71137                  242595.0  2018
# 115275                  78813.0  2020
# 131166                 221049.0  2021
# 97326                  210049.0  2021
# 133143                 332641.0  2021
# 133175                3658455.0  2021
# 95378                  230065.0  2020
# 96923                  621849.0  2020
# 90147                  949401.0  2020
# 94360                  319785.0  2020
# 57469                  210000.0  2017
# 77705                  744444.0  2019
# 75458                   18201.0  2018
# 55092                   62821.0  2016
# 95906                 1354871.0  2019
# 122939                 152680.0  2020
# 127833                 336584.0  2021
# 126103                1354871.0  2021
# 96816                  182437.0  2019
# 102900                  69764.0  2020
# 91726                   91876.0  2020
# 118041                  21692.0  2021
# 131209                  12954.0  2021
# 120566                  42847.0  2020
# 120011                1879815.0  2020
# 89201                   87643.0  2020
# 118358                  11953.0  2020
# 121207                 777341.0  2021
# 120580                7100000.0  2020
# 110296                 751184.0  2022
# 117761                2175909.0  2021
# 112490                 550660.0  2022
# 112063                 773581.0  2022
# 90035                  223467.0  2019
# 116353                 141371.0  2020
# 91988                  252880.0  2020

# %% [markdown]
# There is no clear reason why these 37 agencies are missing 4 dig IDs when others are not.  It will be better to use the '5 DIgit NTD ID' as the unique identifier instead of the '4 Digit NTD ID' since the '5 DIgit NTD ID' data is more complete, but the '4 Digit NTD ID' should be preserved in the dataframe in case it becomes useful for other purposes later on.

# %% [markdown]
# #### 1.6.2.2 Comparing '5 DIgit NTD ID' and 'Agency'
# <a id='1.6.2.2_Comparing_5_DIgit_NTD_ID_and_Agency'></a>

# %% [markdown]
# Finding the reason why there are 608 unique '5 DIgit NTD ID's but only 607 for 'Agency'.

# %% [markdown]
# Creating a dataframe with unique combinations of '5 DIgit NTD ID' plus 'Agency'.  There are 608 rows which matches the number of unique '5 DIgit NTD ID's.

# %%
five_unique_with_agency = data[['5 DIgit NTD ID', 'Agency']].drop_duplicates().sort_values('5 DIgit NTD ID', ascending=True)
five_unique_with_agency
# Out:
#       5 DIgit NTD ID                                             Agency
# 9564           00001            King County Department of Metro Transit
# 3874           00002                          Spokane Transit Authority
# 4828           00003  Pierce County Transportation Benefit Area Auth...
# 6770           00005                                    City of Everett
# 7897           00006                                     City of Yakima
# ...              ...                                                ...
# 36810          91092                      Tahoe Transportation District
# 58760          99422                                San Joaquin Council
# 28663          99423                                   City of Glendale
# 61236          99424                                   City of Pasadena
# 29319          99425             Pomona Valley Transportation Authority
#
# [608 rows x 2 columns]

# %% [markdown]
# Looking to see if a NaN exists in 'Agency' for one of the unique '5 DIgit NTD ID's, but none is found.

# %%
solo = five_unique_with_agency[five_unique_with_agency['Agency'].isnull()]
solo
# Out:
# Empty DataFrame
# Columns: [5 DIgit NTD ID, Agency]
# Index: []

# %% [markdown]
# Looking to see if an agency name appears twice, which it does.

# %%
five_unique_with_agency[five_unique_with_agency.groupby('Agency')['Agency'].transform('size') > 1]
# Out:
#       5 DIgit NTD ID            Agency
# 5497           90034  City of Glendale
# 28663          99423  City of Glendale

# %% [markdown]
# The discrepency between the number of unique '5 DIgit NTD ID's and unique 'Agency' names is due to there being 'City of Glendale' agencies in both Arizona and in California.  There are no errors or missing data.
#
# When using this data later, though, it will need to be sorted by 'Agency' + '5 DIgit NTD ID' or 'Primary UZA Name' in oder for these two agencies to be kept separate.

# %%
data[data['Agency'] == 'City of Glendale'].sort_values('5 DIgit NTD ID')
# Out:
#        5 DIgit NTD ID 4 Digit NTD ID            Agency  \
# 5497            90034           9034  City of Glendale
# 74608           90034           9034  City of Glendale
# 124643          90034           9034  City of Glendale
# 74610           90034           9034  City of Glendale
# 74611           90034           9034  City of Glendale
# ...               ...            ...               ...
# 90040           99423            NaN  City of Glendale
# 90041           99423            NaN  City of Glendale
# 42492           99423            NaN  City of Glendale
# 90022           99423            NaN  City of Glendale
# 90038           99423            NaN  City of Glendale
#
#                                         Organization Type Mode  \
# 5497    City, County or Local Government Unit or Depar...   DR
# 74608   City, County or Local Government Unit or Depar...   DR
# 124643  City, County or Local Government Unit or Depar...   MB
# 74610   City, County or Local Government Unit or Depar...   DR
# 74611   City, County or Local Government Unit or Depar...   DR
# ...                                                   ...  ...
# 90040   City, County or Local Government Unit or Depar...   DR
# 90041   City, County or Local Government Unit or Depar...   DR
# 42492   City, County or Local Government Unit or Depar...   DR
# 90022   City, County or Local Government Unit or Depar...   MB
# 90038   City, County or Local Government Unit or Depar...   DR
#
#        Type of Service Rail (Y/N)  Primary UZA Code  \
# 5497                DO      False                12
# 74608               DO      False                12
# 124643              DO      False                12
# 74610               DO      False                12
# 74611               DO      False                12
# ...                ...        ...               ...
# 90040               PT      False                 2
# 90041               PT      False                 2
# 42492               PT      False                 2
# 90022               PT      False                 2
# 90038               PT      False                 2
#
#                           Primary UZA Name  Primary UZA Sq Miles  ...  \
# 5497                      Phoenix-Mesa, AZ                1147.0  ...
# 74608                     Phoenix-Mesa, AZ                1147.0  ...
# 124643                    Phoenix-Mesa, AZ                1147.0  ...
# 74610                     Phoenix-Mesa, AZ                1147.0  ...
# 74611                     Phoenix-Mesa, AZ                1147.0  ...
# ...                                    ...                   ...  ...
# 90040   Los Angeles-Long Beach-Anaheim, CA                1736.0  ...
# 90041   Los Angeles-Long Beach-Anaheim, CA                1736.0  ...
# 42492   Los Angeles-Long Beach-Anaheim, CA                1736.0  ...
# 90022   Los Angeles-Long Beach-Anaheim, CA                1736.0  ...
# 90038   Los Angeles-Long Beach-Anaheim, CA                1736.0  ...
#
#         Pedestrian in Corsswalk Injuries  \
# 5497                                   0
# 74608                                  0
# 124643                                 0
# 74610                                  0
# 74611                                  0
# ...                                  ...
# 90040                                  0
# 90041                                  0
# 42492                                  0
# 90022                                  0
# 90038                                  0
#
#         Pedestrian Not in Crosswalk Injuries  \
# 5497                                       0
# 74608                                      0
# 124643                                     0
# 74610                                      0
# 74611                                      0
# ...                                      ...
# 90040                                      0
# 90041                                      0
# 42492                                      0
# 90022                                      0
# 90038                                      0
#
#         Pedestrian Crossing Tracks Injuries  \
# 5497                                      0
# 74608                                     0
# 124643                                    0
# 74610                                     0
# 74611                                     0
# ...                                     ...
# 90040                                     0
# 90041                                     0
# 42492                                     0
# 90022                                     0
# 90038                                     0
#
#         Pedestrian Walking Along Tracks Injuries  \
# 5497                                           0
# 74608                                          0
# 124643                                         0
# 74610                                          0
# 74611                                          0
# ...                                          ...
# 90040                                          0
# 90041                                          0
# 42492                                          0
# 90022                                          0
# 90038                                          0
#
#         Other Vehicle Occupant Injuries  Other Injuries  Trespasser Injuries  \
# 5497                                  0               0                    0
# 74608                                 0               0                    0
# 124643                                0               0                    0
# 74610                                 0               0                    0
# 74611                                 0               0                    0
# ...                                 ...             ...                  ...
# 90040                                 0               0                    0
# 90041                                 0               0                    0
# 42492                                 0               0                    0
# 90022                                 0               0                    0
# 90038                                 0               0                    0
#
#         Suicide Injuries  Total Other Injuries  Total Injuries
# 5497                   0                     0               0
# 74608                  0                     0               0
# 124643                 0                     0               0
# 74610                  0                     0               0
# 74611                  0                     0               0
# ...                  ...                   ...             ...
# 90040                  0                     0               0
# 90041                  0                     0               0
# 42492                  0                     0               0
# 90022                  0                     0               0
# 90038                  0                     0               0
#
# [372 rows x 65 columns]

# %% [markdown]
# #### 1.6.2.3 The Winning Combination
# <a id='1.6.2.3_The_Winning_Combination'></a>

# %% [markdown]
# Looking to see if the '5 DIgit NTD ID' is truely a unique identifier.

# %% [markdown]
# There are 608 unique '5 DIgit NTD ID's in the dataframe.

# %%
test_of_uniqueness_1 = data[['5 DIgit NTD ID']].sort_values(['5 DIgit NTD ID'])
test_of_uniqueness_1 = test_of_uniqueness_1.drop_duplicates(subset = ['5 DIgit NTD ID'], keep = 'last')
test_of_uniqueness_1.shape
# Out:
# (608, 1)

# %% [markdown]
# When sorted with 'Agency', there are still 608 rows, which means that each '5 DIgit NTD ID' is represented exactly once.

# %%
test_of_uniqueness_2 = data[['5 DIgit NTD ID','Agency']].sort_values(['5 DIgit NTD ID','Agency'])
test_of_uniqueness_2 = test_of_uniqueness_2.drop_duplicates(subset = ['5 DIgit NTD ID','Agency'], keep = 'last')
test_of_uniqueness_2.shape
# Out:
# (608, 2)

# %% [markdown]
# When sorted with '4 Digit NTD ID', there are still 608 rows, which means that each '5 DIgit NTD ID' is represented exactly once.

# %%
test_of_uniqueness_3 = data[['5 DIgit NTD ID', '4 Digit NTD ID']].sort_values(['5 DIgit NTD ID', '4 Digit NTD ID'])
test_of_uniqueness_3 = test_of_uniqueness_3.drop_duplicates(subset = ['5 DIgit NTD ID','4 Digit NTD ID'], keep = 'last')
test_of_uniqueness_3.shape
# Out:
# (608, 2)

# %% [markdown]
# Caution: When sorted with both 'Agency', and 'Primary UZA Name', there are 611 rows.  This occurs because of the three agencies which each serve and report for two different 'Primary UZA Names'.

# %%
test_of_uniqueness_4 = data[['5 DIgit NTD ID','Agency', 'Primary UZA Name']].sort_values(['5 DIgit NTD ID','Agency', 'Primary UZA Name'])
test_of_uniqueness_4 = test_of_uniqueness_4.drop_duplicates(subset = ['5 DIgit NTD ID','Agency', 'Primary UZA Name'], keep = 'last')
test_of_uniqueness_4.shape
# Out:
# (611, 3)

# %% [markdown]
# The '5 DIgit NTD ID' is a unique identifier for this dataframe.  It is unique to each agency and there is, now that we have cleaned, no missing data in that column.
#
# However, there are two limitations/cautions when using this field by itself and in combination in the search for uniqueness.
#
# 1.  In section 1.6.1.2.2, it was discovered that there were three '5 DIgit NTD ID's which each served and reported for two different 'Primary UZA Name's.  So, dropping duplicates of '5 DIgit NTD ID's would drop one of the two 'Primary UZA Name's and therefore service areas (likely desirable data) for each of the those three agencies.
#
# 2.  Then, in section 1.6.2.2, it was found that two different '5 DIgit NTD ID's were listed with the same 'Agency', but each of those 'Agency's had a unique 'Primary UZA Name' due to them actually being distinct entities in different states.  Dropping duplicate '5 DIgit NTD ID's is not a problem here but caution would need to be taken at other times to make sure the data for the two "City of Glendale" agencies won't unintentially be combined.

# %% [markdown]
# ### 1.6.3 Changing Data Type of 'Rail (Y/N)' Column
# <a id='1.6.3_Rail'></a>

# %% [markdown]
# Removing the NANs in the Agency column also removed the NaNs in the 'Rail (Y/N)' column.  So, the data type can now be changed to bool.

# %%
missing = pd.concat([data.isnull().sum(), 100 * data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing
# Out:
#                                             count         %
# 5 DIgit NTD ID                                  0  0.000000
# 4 Digit NTD ID                               2997  2.250879
# Agency                                          0  0.000000
# Organization Type                              27  0.020278
# Mode                                            0  0.000000
# Type of Service                                 0  0.000000
# Rail (Y/N)                                      0  0.000000
# Primary UZA Code                                0  0.000000
# Primary UZA Name                               27  0.020278
# Primary UZA Sq Miles                           27  0.020278
# Primary UZA Population                         27  0.020278
# Service Area Sq Miles                          27  0.020278
# Service Area Population                        27  0.020278
# Year                                            0  0.000000
# Month                                           0  0.000000
# Vehicles                                        0  0.000000
# Vehicle Revenue Miles                           0  0.000000
# Vehicle Revenue Hours                           0  0.000000
# Ridership                                       0  0.000000
# Collisions with Motor Vehicle                   0  0.000000
# Collisions with Person                          0  0.000000
# Collisions with Fixed Object                    0  0.000000
# Collisions with Rail Vehicle                    0  0.000000
# Collisions with Bus Vehicle                     0  0.000000
# Collisions with Other                           0  0.000000
# Total Collisions                                0  0.000000
# Total Derailments                               0  0.000000
# Total Fires                                     0  0.000000
# Total Security Events                           0  0.000000
# Total Events Not Otherwise Classified           0  0.000000
# Total Events                                    0  0.000000
# Passenger Fatalities                            0  0.000000
# People Waiting or Leaving Fatalities            0  0.000000
# Operator Fatalities                             0  0.000000
# Other Employee Fatalities                       0  0.000000
# Total Employee Fatalities                       0  0.000000
# Other Worker Fatalities                         0  0.000000
# Bicyclist Fatalities                            0  0.000000
# Pedestrian in Crosswalk Fatalities              0  0.000000
# Pedestrian Not in Crosswalk Fatalities          0  0.000000
# Pedestrian Crossing Tracks Fatalities           0  0.000000
# Pedestrian Walking Along Tracks Fatalities      0  0.000000
# Other Vehicle Occupant Fatalities               0  0.000000
# Other Fatalities                                0  0.000000
# Trespasser Fatalities                           0  0.000000
# Suicide Fatalities                              0  0.000000
# Total Other Fatalities                          0  0.000000
# Total Fatalities                                0  0.000000
# Passenger Injuries                              0  0.000000
# People Waiting or Leaving Injuries              0  0.000000
# Operator Injuries                               0  0.000000
# Other Employee Injuries                         0  0.000000
# Total Employee Injuries                         0  0.000000
# Other Worker Injuries                           0  0.000000
# Bicyclist Injuries                              0  0.000000
# Pedestrian in Corsswalk Injuries                0  0.000000
# Pedestrian Not in Crosswalk Injuries            0  0.000000
# Pedestrian Crossing Tracks Injuries             0  0.000000
# Pedestrian Walking Along Tracks Injuries        0  0.000000
# Other Vehicle Occupant Injuries                 0  0.000000
# Other Injuries                                  0  0.000000
# Trespasser Injuries                             0  0.000000
# Suicide Injuries                                0  0.000000
# Total Other Injuries                            0  0.000000
# Total Injuries                                  0  0.000000

# %%
data['Rail (Y/N)'] = data['Rail (Y/N)'].astype(bool)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 133148 entries, 0 to 133190
# Data columns (total 65 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   5 DIgit NTD ID                              133148 non-null  object
#  1   4 Digit NTD ID                              130151 non-null  object
#  2   Agency                                      133148 non-null  object
#  3   Organization Type                           133121 non-null  object
#  4   Mode                                        133148 non-null  object
#  5   Type of Service                             133148 non-null  object
#  6   Rail (Y/N)                                  133148 non-null  bool
#  7   Primary UZA Code                            133148 non-null  int64
#  8   Primary UZA Name                            133121 non-null  object
#  9   Primary UZA Sq Miles                        133121 non-null  float64
#  10  Primary UZA Population                      133121 non-null  float64
#  11  Service Area Sq Miles                       133121 non-null  float64
#  12  Service Area Population                     133121 non-null  float64
#  13  Year                                        133148 non-null  int64
#  14  Month                                       133148 non-null  int64
#  15  Vehicles                                    133148 non-null  int64
#  16  Vehicle Revenue Miles                       133148 non-null  int64
#  17  Vehicle Revenue Hours                       133148 non-null  int64
#  18  Ridership                                   133148 non-null  int64
#  19  Collisions with Motor Vehicle               133148 non-null  int64
#  20  Collisions with Person                      133148 non-null  int64
#  21  Collisions with Fixed Object                133148 non-null  int64
#  22  Collisions with Rail Vehicle                133148 non-null  int64
#  23  Collisions with Bus Vehicle                 133148 non-null  int64
#  24  Collisions with Other                       133148 non-null  int64
#  25  Total Collisions                            133148 non-null  int64
#  26  Total Derailments                           133148 non-null  int64
#  27  Total Fires                                 133148 non-null  int64
#  28  Total Security Events                       133148 non-null  int64
#  29  Total Events Not Otherwise Classified       133148 non-null  int64
#  30  Total Events                                133148 non-null  int64
#  31  Passenger Fatalities                        133148 non-null  int64
#  32  People Waiting or Leaving Fatalities        133148 non-null  int64
#  33  Operator Fatalities                         133148 non-null  int64
#  34  Other Employee Fatalities                   133148 non-null  int64
#  35  Total Employee Fatalities                   133148 non-null  int64
#  36  Other Worker Fatalities                     133148 non-null  int64
#  37  Bicyclist Fatalities                        133148 non-null  int64
#  38  Pedestrian in Crosswalk Fatalities          133148 non-null  int64
#  39  Pedestrian Not in Crosswalk Fatalities      133148 non-null  int64
#  40  Pedestrian Crossing Tracks Fatalities       133148 non-null  int64
#  41  Pedestrian Walking Along Tracks Fatalities  133148 non-null  int64
#  42  Other Vehicle Occupant Fatalities           133148 non-null  int64
#  43  Other Fatalities                            133148 non-null  int64
#  44  Trespasser Fatalities                       133148 non-null  int64
#  45  Suicide Fatalities                          133148 non-null  int64
#  46  Total Other Fatalities                      133148 non-null  int64
#  47  Total Fatalities                            133148 non-null  int64
#  48  Passenger Injuries                          133148 non-null  int64
#  49  People Waiting or Leaving Injuries          133148 non-null  int64
#  50  Operator Injuries                           133148 non-null  int64
#  51  Other Employee Injuries                     133148 non-null  int64
#  52  Total Employee Injuries                     133148 non-null  int64
#  53  Other Worker Injuries                       133148 non-null  int64
#  54  Bicyclist Injuries                          133148 non-null  int64
#  55  Pedestrian in Corsswalk Injuries            133148 non-null  int64
#  56  Pedestrian Not in Crosswalk Injuries        133148 non-null  int64
#  57  Pedestrian Crossing Tracks Injuries         133148 non-null  int64
#  58  Pedestrian Walking Along Tracks Injuries    133148 non-null  int64
#  59  Other Vehicle Occupant Injuries             133148 non-null  int64
#  60  Other Injuries                              133148 non-null  int64
#  61  Trespasser Injuries                         133148 non-null  int64
#  62  Suicide Injuries                            133148 non-null  int64
#  63  Total Other Injuries                        133148 non-null  int64
#  64  Total Injuries                              133148 non-null  int64
# dtypes: bool(1), float64(4), int64(53), object(7)
# memory usage: 66.2+ MB

# %% [markdown]
# ## 1.7 Save Data
# <a id='1.7_Save_Data'></a>

# %%
data.to_csv("data_cleaned.csv")

# %% [markdown]
# ## 1.8 Summary
# <a id='1.8_Summary'></a>

# %% [markdown]
# At the beginning of this notebook the dataframe contained 133,196 rows of data and 65 columns.  Fourty eight rows were found to have no identifiers and so were removed, leaving 133,148 rows of data with no loss of columns.
#
# Over 4000 rows of were found to be missing data in one or more of the 'Primary UZA Name', 'Primary UZA Sq Miles', 'Primary UZA Population', 'Organization Type', 'Service Area Sq Miles', and 'Service Area Population' columns.  All but 27 rows of data were able to be filled using appropriate data found elsewhere in the dataframe.  The 27 rows which remain unfilled are all associate with The East Central Iowa Council of Governments ('5 DIgit NTD ID' 70138).
#
# The '5 DIgit NTD ID', '4 Digit NTD ID', and 'Agency' columns were explored to determine which should be used as the primary identifier going forward.  The '5 DIgit NTD ID' was chosen because it is the only one of the three which has an entry for all of the 133,148 rows of data and which is completely unique for each reporting agency.  However, three different '5 DIgit NTD ID's were each found to be (correctly) associated with two distinct 'Primary UZA Names', and two separate '5 DIgit NTD ID's were found to have 'Agency's of the same name but with distinct 'Primary UZA Name's.  So, caution will be required when sorting data in future notebooks.
#
# The Data Type for the 'Rail (Y/N)' column was changed to 'bool', having been made possible by the removal of all the rows containing NaNs in that column when the 48 rows were removed earlier in the notebook.
#
# During the exploratory data analysis phase of the project, decisions will need to be made about the usefulness of keeping the '4 Digit NTD ID' column, and how to handle the 27 rows of data from The East Central Iowa Council of Governments which still contain NaNs.
