# %% [markdown]
# # Capstone 2: *National Transit Database*
# ## *Preprocessing and Training*
# ***

# %% [markdown]
# ## 3.1 Table of Contents<a id='3.1_Contents'></a>
# * [3 Preprocessing and Training](#3_Preprocessing_and_Training)
#   * [3.1 Table of Contents](#3.1_Contents)
#   * [3.2 Introduction](#3.2_Introduction)
#   * [3.3 Data Dictionary](#3.3_Data_Dictionary)
#   * [3.4 Importing the Dependencies](#3.4_Importing_the_Dependencies)
#   * [3.5 Importing the Data](#3.5_Importing_the_Data)
#   * [3.6 Defining Safety](#3.6_Defining_Safety)
#       * [3.6.1 'Total Events' Column](#3.6.1_Total_Events_Column)
#       * [3.6.2 Drop Columns Captured by 'Total Events'](#3.6.2_Drop_Columns_Captured_by_Total_Events)
#       * [3.6.3 Add 'Cumulative Safety per 100K VRM' Column](#3.6.3_Add_Cumulative_Safety_per_100K_VRM_Column)
#       * [3.6.4 Drop Columns Accounted for in 'Cumulative Safety per 100K VRM'](#3.6.4_Add_Cumulative_Safety_per_100K_VRM_Column)
#   * [3.7 'Primary UZA Code' or 'Primary UZA Population'](#3.7_Primary_UZA_Code_or_Primary_UZA_Population)
#   * [3.8 Looking at the Descriptive Statistics](#3.8_Looking_at_the_Descriptive_Statistics)
#   * [3.9 Encoding the Categorical Features](#3.9_Encoding_the_Categorical_Features)
#   * [3.10 Train/Test Split](#Train_Test_Split)
#   * [3.11 Linear Regression](#3.11_Linear_Regression)
#   * [3.12 Random Forest](#3.12_Random_Forest)

# %% [markdown]
# ## 3.2 Introduction
# <a id='3.2_Introduction'></a>

# %% [markdown]
# ## 3.4 Importing the Dependencies
# <a id='3.4_Importing_the_Dependencies'></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from itertools import groupby
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectKBest, f_regression

pd.set_option('display.max_rows', 70)

# %% [markdown]
# ## 3.5 Importing the Data
# <a id='3.5_Importing_the_Data'></a>

# %%
National_data = pd.read_csv("reduced_data.csv")
Nashville_data = pd.read_csv("Nashville_data.csv")

# %% [markdown]
# ## 3.6 Defining Safety
# <a id='3.6_Defining_Safety'></a>

# %% [markdown]
# The FTA requires covered public transportation providers to establish Safety Performance Measures (SPMs) and use them to set annual Safety Perform Targets (SPTs) based.  These targets must depend only on data submittable to the NTD. Since my goal is to assit Nashville in its decision-making, I will use the SPMs of it's largest NTD reporter to guide my definition of safety.  The SPMs and SPTs for the Metropolitan Transit Authority (MTA) dba WeGo Public Transit can be found on page 8 of this document: [MTA Safety Performance Measures](https://www.wegotransit.com/file.aspx?DocumentId=102).  MTA's chosen SPMs match the example given by the FTA in their Safety Performance Targets Guide which can be found here: [FTA SPT Guide](https://www.transit.dot.gov/sites/fta.dot.gov/files/2021-06/SPTs-Guide-v2-20210629.pdf).

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.6.1 'Total Events' Column
# <a id='3.6.1_Total_Events_Column'></a>
# The NTD database does not have a column called 'Total Safety Events' so I will verify that the 'Toal Events' column is a total of all the events listed in the definition above from given in the [FTA Glossary](https://www.transit.dot.gov/ntd/national-transit-database-ntd-glossary).

# %%
National_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129752 entries, 0 to 129751
# Data columns (total 26 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   5 DIgit NTD ID                         129752 non-null  int64
#  1   Agency                                 129752 non-null  object
#  2   Organization Type                      129752 non-null  object
#  3   Mode                                   129752 non-null  object
#  4   Type of Service                        129752 non-null  object
#  5   Rail (Y/N)                             129752 non-null  bool
#  6   Primary UZA Code                       129752 non-null  float64
#  7   Primary UZA Name                       129752 non-null  object
#  8   Primary UZA Sq Miles                   129752 non-null  float64
#  9   Primary UZA Population                 129752 non-null  float64
#  10  Service Area Sq Miles                  129752 non-null  float64
#  11  Service Area Population                129752 non-null  float64
#  12  Year                                   129752 non-null  int64
#  13  Month                                  129752 non-null  int64
#  14  Vehicles                               129752 non-null  int64
#  15  Vehicle Revenue Miles                  129752 non-null  int64
#  16  Vehicle Revenue Hours                  129752 non-null  int64
#  17  Ridership                              129752 non-null  int64
#  18  Total Collisions                       129752 non-null  int64
#  19  Total Derailments                      129752 non-null  int64
#  20  Total Fires                            129752 non-null  int64
#  21  Total Security Events                  129752 non-null  int64
#  22  Total Events Not Otherwise Classified  129752 non-null  int64
#  23  Total Events                           129752 non-null  int64
#  24  Total Fatalities                       129752 non-null  int64
#  25  Total Injuries                         129752 non-null  int64
# dtypes: bool(1), float64(5), int64(15), object(5)
# memory usage: 24.9+ MB

# %%
#Nashville_data.info()

# %%
#Check to see if 'Total Events" captures all data in columns 'Total Collisions', 'Total Derailments', 'Total Fires',
#'Total Security Events', and 'Total Events Not Otherwise Classified'

National_events = National_data.iloc[:, 18:24]
Nashville_events = Nashville_data.iloc[:, 18:24]
count5 = 0
count6 = 0

for i in National_events.index:
    if sum(National_events.iloc[i,[5]]) != sum(National_events.iloc[i,0:5]):
        count5 += 1
        list5.append(i)

for i in Nashville_events.index:
    if sum(Nashville_events.iloc[i,[5]]) != sum(Nashville_events.iloc[i,0:5]):
        count5 += 1
        list5.append(i)        

print('There are ',count5, "rows where 'Total Events' does not match the sum of the other National columns")
print('There are ',count6, "rows where 'Total Events' does not match the sum of the other Nashville columns")
# Out:
# There are  0 rows where 'Total Events' does not match the sum of the other National columns
# There are  0 rows where 'Total Events' does not match the sum of the other Nashville columns

# %% [markdown]
# Since the 'Total Events' column is confirmed to be the total of the other columns, I can drop the other columns from both the National and Nashville dataframes.

# %% [markdown]
# ### 3.6.2 Drop Columns Captured by 'Total Events'
# <a id='3.6.2_Drop_Columns_Captured_by_Total_Events'></a>

# %%
National_data.shape
# Out:
# (129752, 26)

# %%
Nashville_data.shape
# Out:
# (750, 26)

# %%
National_data = National_data.drop(National_data.iloc[:, 18:23], axis=1)
Nashville_data = Nashville_data.drop(Nashville_data.iloc[:, 18:23], axis=1)

# %%
National_data.shape
# Out:
# (129752, 21)

# %%
Nashville_data.shape
# Out:
# (750, 21)

# %% [markdown]
# ### 3.6.3 Add 'Cumulative Safety per 100K VRM' Column
# <a id='3.6.3_Add_Cumulative_Safety_per_100K_VRM_Column'></a>
# In order to have a single column for y, I will combine the three categories of SPTs (fatalities, injuries, and events) into one and present it as a value per 100,000 VRM.

# %%
National_Cumulative_Safety = (National_data['Total Fatalities'] + National_data['Total Injuries'] + National_data['Total Events'])
Nashville_Cumulative_Safety = (Nashville_data['Total Fatalities'] + Nashville_data['Total Injuries'] + Nashville_data['Total Events'])

National_data['Cumulative Safety per 100K VRM'] = (National_Cumulative_Safety/National_data['Vehicle Revenue Miles'])*100000
Nashville_data['Cumulative Safety per 100K VRM'] = (Nashville_Cumulative_Safety/Nashville_data['Vehicle Revenue Miles'])*100000

# %%
National_data['Cumulative Safety per 100K VRM'].isna().sum()
# Out:
# 1185

# %%
Nashville_data['Cumulative Safety per 100K VRM'].isna().sum()
# Out:
# 0

# %% [markdown]
# In rows where there were no fatalities, injuries, or events, I end up with Nans because I have divided by zero.  I will replace the Nans with zeros since that is the logical value.

# %%
National_data['Cumulative Safety per 100K VRM'].replace([np.inf, -np.inf, np.nan], 0, inplace=True)
National_data['Cumulative Safety per 100K VRM'].isna().sum()
# Out:
# 0

# %%
National_data['Cumulative Safety per 100K VRM'].isna().sum()
# Out:
# 0

# %%
National_data.shape
# Out:
# (129752, 22)

# %% [markdown]
# ### 3.6.4 Drop Columns Accounted for in 'Cumulative Safety per 100K VRM'
# <a id='3.6.4_Add_Cumulative_Safety_per_100K_VRM_Column'></a>
# I can now drop the 'Total Revenue Miles', 'Total Fatalities', 'Total Injuries', and 'Total Events' columns since they are accounted for in my new 'Cumulative Safety per 100K VRM' column.

# %%
National_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129752 entries, 0 to 129751
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   5 DIgit NTD ID                  129752 non-null  int64
#  1   Agency                          129752 non-null  object
#  2   Organization Type               129752 non-null  object
#  3   Mode                            129752 non-null  object
#  4   Type of Service                 129752 non-null  object
#  5   Rail (Y/N)                      129752 non-null  bool
#  6   Primary UZA Code                129752 non-null  float64
#  7   Primary UZA Name                129752 non-null  object
#  8   Primary UZA Sq Miles            129752 non-null  float64
#  9   Primary UZA Population          129752 non-null  float64
#  10  Service Area Sq Miles           129752 non-null  float64
#  11  Service Area Population         129752 non-null  float64
#  12  Year                            129752 non-null  int64
#  13  Month                           129752 non-null  int64
#  14  Vehicles                        129752 non-null  int64
#  15  Vehicle Revenue Miles           129752 non-null  int64
#  16  Vehicle Revenue Hours           129752 non-null  int64
#  17  Ridership                       129752 non-null  int64
#  18  Total Events                    129752 non-null  int64
#  19  Total Fatalities                129752 non-null  int64
#  20  Total Injuries                  129752 non-null  int64
#  21  Cumulative Safety per 100K VRM  129752 non-null  float64
# dtypes: bool(1), float64(6), int64(10), object(5)
# memory usage: 20.9+ MB

# %%
National_data = National_data.drop(National_data.iloc[:, np.r_[15, 18, 19, 20]], axis=1)
Nashville_data = Nashville_data.drop(Nashville_data.iloc[:, np.r_[15, 18, 19, 20]], axis=1)

# %%
National_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129752 entries, 0 to 129751
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   5 DIgit NTD ID                  129752 non-null  int64
#  1   Agency                          129752 non-null  object
#  2   Organization Type               129752 non-null  object
#  3   Mode                            129752 non-null  object
#  4   Type of Service                 129752 non-null  object
#  5   Rail (Y/N)                      129752 non-null  bool
#  6   Primary UZA Code                129752 non-null  float64
#  7   Primary UZA Name                129752 non-null  object
#  8   Primary UZA Sq Miles            129752 non-null  float64
#  9   Primary UZA Population          129752 non-null  float64
#  10  Service Area Sq Miles           129752 non-null  float64
#  11  Service Area Population         129752 non-null  float64
#  12  Year                            129752 non-null  int64
#  13  Month                           129752 non-null  int64
#  14  Vehicles                        129752 non-null  int64
#  15  Vehicle Revenue Hours           129752 non-null  int64
#  16  Ridership                       129752 non-null  int64
#  17  Cumulative Safety per 100K VRM  129752 non-null  float64
# dtypes: bool(1), float64(6), int64(6), object(5)
# memory usage: 17.0+ MB

# %% [markdown]
# ## 3.7 'Primary UZA Code' or 'Primary UZA Population'
# <a id='3.7_Primary_UZA_Code_or_Primary_UZA_Population'></a>
#
# **Housekeeping:** I want to take one more citical look at the columns I have left so make decisions about redundancy.  'Primary UZA Code' and 'Primary UZA Population' or both ordinal representations of the ranking of population size.  However, 'Primary UZA Code' has the one value (602) which is out of place.  Remove the 'Primary UZA Code' column will not result in any loss of data and will align the two columns representing UZAs with the two columns representing service areas.  (Both will have columns for Sq Miles and Population.)  'Primary UZA Name' will be kept as an object field.

# %%
National_data = National_data.drop(['Primary UZA Code'], axis=1)
Nashville_data = Nashville_data.drop(['Primary UZA Code'], axis=1)

# %% [markdown]
# ## 3.8 Looking at the Descriptive Statistics
# <a id= '3.8_Looking_at_the_Descriptive_Statistics'></a>
# Taking a quick look at the statistics for each dataframe before moving on.

# %%
National_data.describe()
# Out:
#        5 DIgit NTD ID  Primary UZA Sq Miles  Primary UZA Population  \
# count   129752.000000         129752.000000            1.297520e+05
# mean     48464.816226            666.536030            2.495346e+06
# std      27788.335635            845.091874            4.256806e+06
# min          1.000000             11.000000            5.124000e+04
# 25%      30034.000000             92.000000            2.089480e+05
# 50%      50010.000000            296.000000            6.213000e+05
# 75%      70010.000000            905.000000            2.650890e+06
# max      99425.000000           3450.000000            1.835130e+07
#
#        Service Area Sq Miles  Service Area Population           Year  \
# count          129752.000000             1.297520e+05  129752.000000
# mean              660.358268             1.001718e+06    2017.758840
# std              1271.862208             1.805668e+06       2.458633
# min                 1.000000             1.000000e+00    2014.000000
# 25%                74.000000             1.543460e+05    2016.000000
# 50%               251.000000             3.417180e+05    2018.000000
# 75%               683.000000             9.295430e+05    2020.000000
# max             15355.000000             1.835130e+07    2022.000000
#
#                Month       Vehicles  Vehicle Revenue Hours     Ridership  \
# count  129752.000000  129752.000000           1.297520e+05  1.297520e+05
# mean        6.326099      79.744952           1.715746e+04  5.476498e+05
# std         3.448032     240.181052           6.550478e+04  5.979668e+06
# min         1.000000       0.000000           0.000000e+00  0.000000e+00
# 25%         3.000000      10.000000           1.404000e+03  4.588750e+03
# 50%         6.000000      23.000000           3.800000e+03  1.989350e+04
# 75%         9.000000      56.000000           1.069625e+04  1.223390e+05
# max        12.000000    5413.000000           1.833647e+06  2.536099e+08
#
#        Cumulative Safety per 100K VRM
# count                   129752.000000
# mean                         0.353434
# std                          3.060403
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                        609.756098

# %%
Nashville_data.describe()
# Out:
#        5 DIgit NTD ID  Primary UZA Sq Miles  Primary UZA Population  \
# count      750.000000                 750.0                   750.0
# mean     40090.904000                 563.0                969587.0
# std         79.849433                   0.0                     0.0
# min      40004.000000                 563.0                969587.0
# 25%      40004.000000                 563.0                969587.0
# 50%      40159.000000                 563.0                969587.0
# 75%      40159.000000                 563.0                969587.0
# max      40178.000000                 563.0                969587.0
#
#        Service Area Sq Miles  Service Area Population         Year  \
# count             750.000000             7.500000e+02   750.000000
# mean             1494.856000             1.216144e+06  2017.656000
# std              2307.369812             5.123273e+05     2.461248
# min               484.000000             6.266810e+05  2014.000000
# 25%               484.000000             6.912430e+05  2016.000000
# 50%               750.000000             1.583115e+06  2018.000000
# 75%               750.000000             1.583115e+06  2020.000000
# max              7505.000000             1.978890e+06  2022.000000
#
#             Month    Vehicles  Vehicle Revenue Hours      Ridership  \
# count  750.000000  750.000000              750.00000     750.000000
# mean     6.332000   42.538667             7748.25200  102767.350667
# std      3.450263   38.606335            12879.89757  232536.958736
# min      1.000000    4.000000              113.00000     872.000000
# 25%      3.000000   18.000000              803.75000    7704.500000
# 50%      6.000000   29.000000             1299.50000   14657.000000
# 75%      9.000000   51.000000            10412.50000   25214.000000
# max     12.000000  157.000000            46452.00000  899840.000000
#
#        Cumulative Safety per 100K VRM
# count                      750.000000
# mean                         0.219111
# std                          1.084786
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                         21.978900

# %% [markdown]
# It is clear that the data would benefit from scaling.  I will address this later in the notebook.

# %%
#National_data.info()

# %% [markdown]
# ## 3.9 Encoding the Categorical Features
# <a id= '3.9_Encoding_the_Categorical_Features'></a>
# Time to encode the categorical variables

# %%
National_data['Organization Type'].value_counts()
# Out:
# Independent Public Agency or Authority of Transit Service                68469
# City, County or Local Government Unit or Department of Transportation    46395
# MPO, COG or Other Planning Agency                                         2790
# State Government Unit or Department of Transportation                     2304
# Other Publicly-Owned or Privately Chartered Corporation                   1918
# Subsidiary Unit of a Transit Agency, Reporting Separately                 1866
# Private-Non-Profit Corporation                                            1721
# Private-For-Profit Corporation                                            1573
# University                                                                1278
# Private Provider Reporting on Behalf of a Public Entity                   1180
# Other                                                                      132
# Consolidated Reporter                                                      126
# Name: Organization Type, dtype: int64

# %%
National_data['Organization Type'] = National_data['Organization Type'].map({
    'Independent Public Agency or Authority of Transit Service' : 'A',
    'Subsidiary Unit of a Transit Agency, Reporting Separately' : 'F',
    'City, County or Local Government Unit or Department of Transportation': 'B',
    'University': 'I',
    'Consolidated Reporter': 'L',
    'Other': 'K',
    'Private-For-Profit Corporation': 'H',
    'Private Provider Reporting on Behalf of a Public Entity': 'J',
    'MPO, COG or Other Planning Agency': 'C',
    'State Government Unit or Department of Transportation': 'D',
    'Private-Non-Profit Corporation': 'G',
    'Other Publicly-Owned or Privately Chartered Corporation': 'E'})

# %%
National_data['Organization Type'].value_counts()
# Out:
# A    68469
# B    46395
# C     2790
# D     2304
# E     1918
# F     1866
# G     1721
# H     1573
# I     1278
# J     1180
# K      132
# L      126
# Name: Organization Type, dtype: int64

# %%
National_data = pd.get_dummies(National_data, columns=['Mode','Organization Type','Type of Service'], prefix=['M','OT','ToS'])
Nashville_data = pd.get_dummies(Nashville_data, columns=['Mode','Organization Type','Type of Service'], prefix=['M','OT','ToS'])

# %%
National_data.shape
# Out:
# (129752, 44)

# %%
Nashville_data.shape
# Out:
# (750, 24)

# %%
National_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129752 entries, 0 to 129751
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   5 DIgit NTD ID                  129752 non-null  int64
#  1   Agency                          129752 non-null  object
#  2   Rail (Y/N)                      129752 non-null  bool
#  3   Primary UZA Name                129752 non-null  object
#  4   Primary UZA Sq Miles            129752 non-null  float64
#  5   Primary UZA Population          129752 non-null  float64
#  6   Service Area Sq Miles           129752 non-null  float64
#  7   Service Area Population         129752 non-null  float64
#  8   Year                            129752 non-null  int64
#  9   Month                           129752 non-null  int64
#  10  Vehicles                        129752 non-null  int64
#  11  Vehicle Revenue Hours           129752 non-null  int64
#  12  Ridership                       129752 non-null  int64
#  13  Cumulative Safety per 100K VRM  129752 non-null  float64
#  14  M_CB                            129752 non-null  uint8
#  15  M_CC                            129752 non-null  uint8
#  16  M_CR                            129752 non-null  uint8
#  17  M_DR                            129752 non-null  uint8
#  18  M_HR                            129752 non-null  uint8
#  19  M_LR                            129752 non-null  uint8
#  20  M_MB                            129752 non-null  uint8
#  21  M_MG                            129752 non-null  uint8
#  22  M_RB                            129752 non-null  uint8
#  23  M_SR                            129752 non-null  uint8
#  24  M_TB                            129752 non-null  uint8
#  25  M_TR                            129752 non-null  uint8
#  26  M_VP                            129752 non-null  uint8
#  27  M_YR                            129752 non-null  uint8
#  28  OT_A                            129752 non-null  uint8
#  29  OT_B                            129752 non-null  uint8
#  30  OT_C                            129752 non-null  uint8
#  31  OT_D                            129752 non-null  uint8
#  32  OT_E                            129752 non-null  uint8
#  33  OT_F                            129752 non-null  uint8
#  34  OT_G                            129752 non-null  uint8
#  35  OT_H                            129752 non-null  uint8
#  36  OT_I                            129752 non-null  uint8
#  37  OT_J                            129752 non-null  uint8
#  38  OT_K                            129752 non-null  uint8
#  39  OT_L                            129752 non-null  uint8
#  40  ToS_DO                          129752 non-null  uint8
#  41  ToS_PT                          129752 non-null  uint8
#  42  ToS_TN                          129752 non-null  uint8
#  43  ToS_TX                          129752 non-null  uint8
# dtypes: bool(1), float64(5), int64(6), object(2), uint8(30)
# memory usage: 16.7+ MB

# %%
Nashville_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 24 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   5 DIgit NTD ID                                                750 non-null    int64
#  1   Agency                                                        750 non-null    object
#  2   Rail (Y/N)                                                    750 non-null    bool
#  3   Primary UZA Name                                              750 non-null    object
#  4   Primary UZA Sq Miles                                          750 non-null    float64
#  5   Primary UZA Population                                        750 non-null    float64
#  6   Service Area Sq Miles                                         750 non-null    float64
#  7   Service Area Population                                       750 non-null    float64
#  8   Year                                                          750 non-null    int64
#  9   Month                                                         750 non-null    int64
#  10  Vehicles                                                      750 non-null    int64
#  11  Vehicle Revenue Hours                                         750 non-null    int64
#  12  Ridership                                                     750 non-null    int64
#  13  Cumulative Safety per 100K VRM                                750 non-null    float64
#  14  M_CB                                                          750 non-null    uint8
#  15  M_CR                                                          750 non-null    uint8
#  16  M_DR                                                          750 non-null    uint8
#  17  M_MB                                                          750 non-null    uint8
#  18  M_VP                                                          750 non-null    uint8
#  19  OT_Independent Public Agency or Authority of Transit Service  750 non-null    uint8
#  20  OT_Private Provider Reporting on Behalf of a Public Entity    750 non-null    uint8
#  21  ToS_DO                                                        750 non-null    uint8
#  22  ToS_PT                                                        750 non-null    uint8
#  23  ToS_TX                                                        750 non-null    uint8
# dtypes: bool(1), float64(5), int64(6), object(2), uint8(10)
# memory usage: 84.4+ KB

# %% [markdown]
# ## 3.10 Train/Test Split
# <a id= 'Train_Test_Split'></a>

# %%
#Defining X and y from National_data

X_National = National_data.drop(['Cumulative Safety per 100K VRM'], axis = 1)
y_National = National_data['Cumulative Safety per 100K VRM']

# %%
# Train/Test split

X_train, X_test, y_train, y_test = train_test_split(X_National, y_National, test_size=0.2)
#X_train.info()

# %%
# Saving categorical columns separately and removing them from train and test

National_categorical_list = ['5 DIgit NTD ID', 'Agency', 'Primary UZA Name']
National_categorical_train = X_train[National_categorical_list]
National_categorical_test = X_test[National_categorical_list]
X_train.drop(columns = National_categorical_list, inplace = True)
X_test.drop(columns = National_categorical_list, inplace = True)
X_train.shape, X_test.shape
# Out:
# ((103801, 40), (25951, 40))

# %% [markdown]
# ## 3.11 Linear Regression
# <a id= '3.11_Linear_Regression'></a>

# %%
lr_pipe = make_pipeline(StandardScaler(), SelectKBest(f_regression), LinearRegression())

k = [k+1 for k in range(len(X_train.columns))]
params = {'selectkbest__k': k}

lr_grid_cv = GridSearchCV(lr_pipe, param_grid=params, cv=5, n_jobs=-1)
lr_grid_cv.fit(X_train, y_train)

score_mean = lr_grid_cv.cv_results_['mean_test_score']
score_std = lr_grid_cv.cv_results_['std_test_score']
cv_k = [k for k in lr_grid_cv.cv_results_['param_selectkbest__k']]


lr_grid_cv.best_params_
# Out:
# {'selectkbest__k': 39}

# %%
#Save best k and plot
best_k = lr_grid_cv.best_params_['selectkbest__k']
plt.subplots(figsize=(10, 5))
plt.errorbar(cv_k, score_mean, yerr=score_std)
plt.axvline(x=best_k, c='r', ls='--', alpha=.5)
plt.xlabel('k')
plt.ylabel('CV score (r-squared)')
plt.title('Pipeline mean CV score (error bars +/- 1sd)');

# %%
selected = lr_grid_cv.best_estimator_.named_steps.selectkbest.get_support()

coefs = lr_grid_cv.best_estimator_.named_steps.linearregression.coef_
features = X_train.columns[selected]
pd.Series(coefs, index=features).sort_values(ascending=False)
# Out:
# OT_A                       4.248510e+12
# OT_B                       4.076726e+12
# M_DR                       2.619248e+12
# M_MB                       2.570364e+12
# M_CB                       1.391017e+12
# M_VP                       1.296409e+12
# OT_C                       1.237474e+12
# OT_D                       1.129003e+12
# OT_E                       1.016330e+12
# OT_F                       1.015330e+12
# OT_G                       9.792797e+11
# OT_H                       9.272008e+11
# OT_I                       8.496225e+11
# OT_J                       8.091887e+11
# M_CR                       7.532916e+11
# M_LR                       7.132420e+11
# M_SR                       6.349145e+11
# M_HR                       5.798487e+11
# M_RB                       5.051202e+11
# M_MG                       3.770214e+11
# M_YR                       3.449691e+11
# M_TB                       3.376899e+11
# OT_L                       2.679588e+11
# OT_K                       2.613804e+11
# M_TR                       1.560684e+11
# M_CC                       1.518826e+11
# Rail (Y/N)                 5.928061e+09
# Primary UZA Sq Miles       2.526445e-01
# Vehicle Revenue Hours      2.030075e-01
# Service Area Population    2.962422e-02
# Month                      1.068916e-02
# Year                      -1.663971e-02
# Ridership                 -7.705939e-02
# Vehicles                  -1.051792e-01
# Primary UZA Population    -2.213026e-01
# ToS_TN                    -1.514930e+11
# ToS_TX                    -8.504673e+11
# ToS_PT                    -1.909042e+12
# ToS_DO                    -1.928901e+12
# dtype: float64

# %%
# linear regression with cross validation where k=bestk

# %% [markdown]
# ## 3.12 Random Forest
# <a id= '3.12_Random_Forest'></a>

# %%
rf2_pipe = make_pipeline(StandardScaler(), RandomForestRegressor(random_state=42))
rf_cv_results = cross_validate(rf2_pipe, X_train, y_train, cv=5)
rf_cv_scores = rf_cv_results['test_score']
rf_cv_scores

# %%
np.mean(rf_cv_scores), np.std(rf_cv_scores)

# %%
n_est = [int(n) for n in np.logspace(start=1, stop=3, num=20)]
grid_params = {
        'randomforestregressor__n_estimators': n_est,
        'standardscaler': [StandardScaler(), None],
}
grid_params

# %%
#rf_rand_cv = RandomizedSearchCV(rf2_pipe, param_distributions=grid_params, cv=5)

# %%
#rf_rand_cv.fit(X_train, y_train)

# %%
#rf_rand_cv = GridSearchCV(rf2_pipe, param_grid=grid_params, cv=5)

# %%
#rf_rand_cv.fit(X_train, y_train)

# %%
#rf_rand_cv.best_params_

# %%
#rf_best_cv_results = cross_validate(rf_rand_cv.best_estimator_, X_train, y_train, cv=5)
rf_best_scores = rf_best_cv_results['test_score']
rf_best_scores

# %%
#np.mean(rf_best_scores), np.std(rf_best_scores)

# %%
#plt.subplots(figsize=(10, 5))
#imps = rf_grid_cv.best_estimator_.named_steps.randomforestregressor.feature_importances_
#rf_feat_imps = pd.Series(imps, index=X_train.columns).sort_values(ascending=False)
#rf_feat_imps.plot(kind='bar')
#plt.xlabel('features')
#plt.ylabel('importance')
#plt.title('Best random forest regressor feature importances');
