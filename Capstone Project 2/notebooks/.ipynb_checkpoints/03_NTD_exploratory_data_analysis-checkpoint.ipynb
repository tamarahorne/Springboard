# %% [markdown]
# start

# %%
#import file

#object_name = pd.read_csv(“file_name.csv”)

# %% [markdown]
# Note to Self: FTA regions [FTA Regions](https://www.transit.dot.gov/about/regional-offices/regional-offices) This addition resource may or may not be useful later.

# %% [markdown]
# ### 1.6.3 Ridership
# <a id='1.6.3_Ridership'></a>

# %% [markdown]
# <div class="alert alert-danger">
# <strong>Note to self:</strong>
#
# How shall I treat the rows where Ridership is zero?  What can we understand from a zero in that field? Is that a true representation of the ridership during those months or is the zero a placeholder?
#
# Possible options:
# * Exclude the data
#
# * Leave as is
#
# * Replace with an average - multiple methods possible to do this
#
# I need to have a better understanding of why ridership is zero during these months/years before I can make a decision.</div>

# %%
data[['5 DIgit NTD ID','Agency','Month','Year','Ridership']].sort_values(by = ['Ridership', '5 DIgit NTD ID','Year','Month'], ascending=True).head(30)
# Out:
#        5 DIgit NTD ID                     Agency  Month  Year  Ridership
# 7933            00006             City of Yakima      1  2014          0
# 7934            00006             City of Yakima      2  2014          0
# 7935            00006             City of Yakima      3  2014          0
# 7936            00006             City of Yakima      4  2014          0
# 7937            00006             City of Yakima      5  2014          0
# 106373          00006             City of Yakima      4  2020          0
# 106374          00006             City of Yakima      5  2020          0
# 106375          00006             City of Yakima      6  2020          0
# 106376          00006             City of Yakima      7  2020          0
# 106377          00006             City of Yakima      8  2020          0
# 106378          00006             City of Yakima      9  2020          0
# 100696          00012  Municipality of Anchorage      5  2020          0
# 37697           00016        RiverCities Transit      7  2016          0
# 37700           00016        RiverCities Transit     10  2016          0
# 37701           00016        RiverCities Transit     11  2016          0
# 57609           00016        RiverCities Transit      2  2017          0
# 57610           00016        RiverCities Transit      3  2017          0
# 57611           00016        RiverCities Transit      4  2017          0
# 57612           00016        RiverCities Transit      5  2017          0
# 57613           00016        RiverCities Transit      6  2017          0
# 57614           00016        RiverCities Transit      7  2017          0
# 102917          00019          Intercity Transit      5  2020          0
# 102940          00019          Intercity Transit      5  2020          0
# 102941          00019          Intercity Transit      6  2020          0
# 102942          00019          Intercity Transit      7  2020          0
# 102943          00019          Intercity Transit      8  2020          0
# 102944          00019          Intercity Transit      9  2020          0
# 102945          00019          Intercity Transit     10  2020          0
# 102946          00019          Intercity Transit     11  2020          0
# 102947          00019          Intercity Transit     12  2020          0

# %% [markdown]
# <div class="alert alert-info">
#   <strong>Checking "Ridership": </strong> There are 1562 rows of data where "Ridership" is zero.</a></div>

# %%
data[data['Ridership']==0].shape
# Out:
# (1562, 65)

# %% [markdown]
# <div class="alert alert-info">
#   <strong>Checking "Ridership": </strong> Looking at one index number from above to see it's data.  At least it is consistent, zero safety data for zero riders.  I checked several fields but will need to do a more diligent exploration before being able to decide what to do with the 1562 rows.</a></div>

# %%
data.iloc[57611]
# Out:
# 5 DIgit NTD ID                                                                            00016
# 4 Digit NTD ID                                                                             0016
# Agency                                                                      RiverCities Transit
# Organization Type                             City, County or Local Government Unit or Depar...
# Mode                                                                                         VP
# Type of Service                                                                              DO
# Rail (Y/N)                                                                                False
# Primary UZA Code                                                                            431
# Primary UZA Name                                                                Longview, WA-OR
# Primary UZA Sq Miles                                                                       33.0
# Primary UZA Population                                                                  63952.0
# Service Area Sq Miles                                                                      31.0
# Service Area Population                                                                 61598.0
# Year                                                                                       2017
# Month                                                                                         7
# Vehicles                                                                                      0
# Vehicle Revenue Miles                                                                         0
# Vehicle Revenue Hours                                                                         0
# Ridership                                                                                     0
# Collisions with Motor Vehicle                                                                 0
# Collisions with Person                                                                        0
# Collisions with Fixed Object                                                                  0
# Collisions with Rail Vehicle                                                                  0
# Collisions with Bus Vehicle                                                                   0
# Collisions with Other                                                                         0
# Total Collisions                                                                              0
# Total Derailments                                                                             0
# Total Fires                                                                                   0
# Total Security Events                                                                         0
# Total Events Not Otherwise Classified                                                         0
# Total Events                                                                                  0
# Passenger Fatalities                                                                          0
# People Waiting or Leaving Fatalities                                                          0
# Operator Fatalities                                                                           0
# Other Employee Fatalities                                                                     0
# Total Employee Fatalities                                                                     0
# Other Worker Fatalities                                                                       0
# Bicyclist Fatalities                                                                          0
# Pedestrian in Crosswalk Fatalities                                                            0
# Pedestrian Not in Crosswalk Fatalities                                                        0
# Pedestrian Crossing Tracks Fatalities                                                         0
# Pedestrian Walking Along Tracks Fatalities                                                    0
# Other Vehicle Occupant Fatalities                                                             0
# Other Fatalities                                                                              0
# Trespasser Fatalities                                                                         0
# Suicide Fatalities                                                                            0
# Total Other Fatalities                                                                        0
# Total Fatalities                                                                              0
# Passenger Injuries                                                                            0
# People Waiting or Leaving Injuries                                                            0
# Operator Injuries                                                                             0
# Other Employee Injuries                                                                       0
# Total Employee Injuries                                                                       0
# Other Worker Injuries                                                                         0
# Bicyclist Injuries                                                                            0
# Pedestrian in Corsswalk Injuries                                                              0
# Pedestrian Not in Crosswalk Injuries                                                          0
# Pedestrian Crossing Tracks Injuries                                                           0
# Pedestrian Walking Along Tracks Injuries                                                      0
# Other Vehicle Occupant Injuries                                                               0
# Other Injuries                                                                                0
# Trespasser Injuries                                                                           0
# Suicide Injuries                                                                              0
# Total Other Injuries                                                                          0
# Total Injuries                                                                                0
# Name: 57614, dtype: object

# %% [markdown]
# ### 1.6.4 TOS TN
# <a id='1.6.4_TOS_TN'></a>

# %% [markdown]
# <div class="alert alert-info">
#   <strong>Type of Service (TOS) "TN":  </strong> It is important to note that this one type of service was not in effect for the entire life of the database since this may change how we use this field.  The documention from NTD shows the new TOS designation "TN" came into use Sept 2019 but it first occurs in the database July 2018. It is used regularly after that.</div>

# %%
temp_df = data[data['Type of Service']=='TN']
temp_df[['Agency','Mode', 'Month','Year','Type of Service']].sort_values(by=['Year','Month'],ascending=True).head(10)
# Out:
#                                            Agency Mode  Month  Year  \
# 74105  The Eastern Contra Costa Transit Authority   DR      7  2018
# 74106  The Eastern Contra Costa Transit Authority   DR      8  2018
# 74107  The Eastern Contra Costa Transit Authority   DR      9  2018
# 74108  The Eastern Contra Costa Transit Authority   DR     10  2018
# 74109  The Eastern Contra Costa Transit Authority   DR     11  2018
# 74110  The Eastern Contra Costa Transit Authority   DR     12  2018
# 74111  The Eastern Contra Costa Transit Authority   DR      1  2019
# 74112  The Eastern Contra Costa Transit Authority   DR      2  2019
# 74113  The Eastern Contra Costa Transit Authority   DR      3  2019
# 74114  The Eastern Contra Costa Transit Authority   DR      4  2019
#
#       Type of Service
# 74105              TN
# 74106              TN
# 74107              TN
# 74108              TN
# 74109              TN
# 74110              TN
# 74111              TN
# 74112              TN
# 74113              TN
# 74114              TN
